# %%
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from scipy.signal import find_peaks
from scipy import signal
from scipy.integrate import trapz
from scipy.interpolate import interp1d
import seaborn as sns
import heartpy as hp
import os
import pickle
import warnings
warnings.simplefilter('ignore', np.RankWarning)

# %%
def plt_performance(history, path='./', filename=''):
    epoch = list(range(0,len(history.history['loss'])))
    
    fig, (his_accuracy, his_loss) = plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)
    his_loss.plot(epoch, history.history['loss'], label='Training loss')
    his_loss.plot(epoch, history.history['val_loss'], label='Validation loss')
    his_loss.set_xlabel("Epochs", fontsize=14)
    his_loss.set_ylabel("Loss", fontsize=14)
    his_loss.set_title("Loss", fontsize=14)
    his_loss.legend(loc='best')
    
    his_accuracy.plot(epoch, history.history['acc'], label='Training accuracy')
    his_accuracy.plot(epoch, history.history['val_acc'], label='Validation accuracy')
    his_accuracy.set_xlabel("Epochs", fontsize=14)
    his_accuracy.set_ylabel("Accuracy", fontsize=14)
    his_accuracy.set_title("Accuracy", fontsize=14)
    his_accuracy.legend(loc='best')
    
    fig.tight_layout()
    if filename == '':
        plt.savefig(f'{path}/performance.png', bbox_inches='tight')
    else:
        plt.savefig(f'{path}/{filename}.png', bbox_inches='tight')
        
"""
Pre-processing method
"""

# def preprocessing(PPG_data):
#     """
#     Fast Emotion Recognition reference
#     """

#     index = 0
#     x = list(range(0,len(PPG_data[0])))
    
#     for PPG in PPG_data:
#         poly = np.polyfit(x, PPG, deg=50)
#         polied = np.polyval(poly, x)
#         detrended = PPG - polied
#         PPG_data[index] = detrended
#         index += 1
        
#     return PPG_data


def preprocessing(ppg_data, view = False, participant = ''):
    """
    Analysis PPG signal reference
    """
    
    # moving average function
    m_avg = lambda t, x, w : (np.asarray([t[i] for i in range(w, len(x) - w)]),
                          np.convolve(x, np.ones((2*w + 1, )) / (2*w + 1),
                                      mode = 'valid'))

    fs = len(ppg_data)/(60)  # sample rate

    # moving average
    w_size = int(fs*.5)  # width of moving window
    times = list(range(0,len(ppg_data)))
    mt, ms = m_avg(times, ppg_data, w_size)

    sign = (ppg_data[w_size:-w_size]-ms)

    analytical_signal = np.abs(signal.hilbert(sign))

    fs = len(sign) / (max(mt) - min(mt))
    w_size = int(fs)
    mt_new, mov_avg = m_avg(mt, analytical_signal, w_size)

    signal_pure = sign[w_size : -w_size] / mov_avg
    
    if view:
        plt.ioff()
        
        fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, ncols = 1, figsize = (10, 8), sharex=True)
        ax1.plot(times, ppg_data, "b-", label="Original")
        ax1.legend(loc='best')
        ax1.set_title("participants"+str(participant)+" Raw", fontsize=14)#, fontweight="bold")

        ax2.plot(mt, sign, 'r-', label="Pure signal")
        ax2.plot(mt_new, mov_avg, 'b-', label='Modulation', alpha=.5)
        ax2.legend(loc='best')
        ax2.set_title("Raw -> filtered", fontsize=14)#, fontweight="bold")

        ax3.plot(mt_new, signal_pure, "g-", label="Demodulated")
        ax3.set_xlim(0, mt[-1])
        ax3.set_title("Raw -> filtered -> demodulated", fontsize=14)#, fontweight="bold")

        ax3.set_xlabel("Time (sec)", fontsize=14) # common axis label
        ax3.legend(loc='best')

        fig.tight_layout()
        plt.savefig(f'./plot_img/{participant}.png', bbox_inches='tight')
        
    return signal_pure

    
def get_peaks(ppg_processed):
    diff_sig_2 = np.diff(ppg_processed) ## do
    peaks_2, _ = find_peaks(diff_sig_2, distance=100*(30/60), prominence=0.01)
    result = []
    peaks = []
    
    for i in range(len(peaks_2)):
        if diff_sig_2[peaks_2][i] > 40:
            result.append(peaks_2[i])
            peaks.append(diff_sig_2[peaks_2][i])
            
    return result, peaks, diff_sig_2

# %%
dir_list_ = os.listdir("./data")
dir_list_.sort()
count = 0
dir_list = []
for i in range(22):
    dir_list.append(dir_list_[i])
    
#### pop unavailable data
dir_list.pop(5)
dir_list.pop(2)

print(dir_list)
df_PPG = pd.DataFrame(columns=['participant','video_number','ppg','valence','arousal'])
Valence_data = []
Arousal_data = []
PPG_data = []

file_num = 0
for file in dir_list:
    dat_file = f'./data/{file}'
    with open(dat_file, 'rb') as f:
        Channel_data = pickle.load(f,encoding='latin1')
    data = Channel_data["data"]
    labels = Channel_data["labels"]
    for video_num in range(40):
        dataP = data[video_num,38]
        dataP = dataP[384:]
        
        label = labels[video_num]
        if label[0] < 5:
            Valence = 0
        if label[0] >= 5:
            Valence = 1
        if label[1] < 5:
            Arousal = 0
        if label[1] >= 5:
            Arousal = 1
        instance = [(file_num, video_num, dataP, Valence, Arousal)]
        new_instance = pd.DataFrame(instance, columns=['participant','video_number','ppg','valence','arousal'])
        df_PPG = pd.concat([df_PPG, new_instance], ignore_index = True)
        PPG_data.append(dataP)
        Valence_data.append(Valence)
        Arousal_data.append(Arousal)
    file_num += 1
    
PPG_shape = np.array(PPG_data)
PPG_shape.shape
# Out:
# ['s01.dat', 's02.dat', 's04.dat', 's05.dat', 's07.dat', 's08.dat', 's09.dat', 's10.dat', 's11.dat', 's12.dat', 's13.dat', 's14.dat', 's15.dat', 's16.dat', 's17.dat', 's18.dat', 's19.dat', 's20.dat', 's21.dat', 's22.dat']
# (800, 7680)

# %% [raw]
# PPG_data = df_PPG['ppg']
#
# preprocessed = preprocessing(PPG_data)

# %%
preprocessed = []

for PPG in PPG_data:
    preprocessed_d = preprocessing(PPG,view=False)
    preprocessed.append(preprocessed_d)

# %%
# Concatenate PPG data of each person to use min-max normalization method 
i = 1
new_PPG = []
tmp_PPG = np.empty(0)
for PPG in preprocessed:
    if i % 40 != 0:
        tmp_PPG = np.concatenate([tmp_PPG, PPG])
    else:
        tmp_PPG = np.concatenate([tmp_PPG, PPG])
        new_PPG.append(tmp_PPG)
        tmp_PPG = np.empty(0)
    i += 1
    
    
# Normalize personal PPG data and Split into per video
new_PPG = np.array(new_PPG)
new_PPG.shape[0]
new_PPG = new_PPG.reshape(new_PPG.shape[0],new_PPG.shape[1],1)

normalized = []

for PPG in new_PPG:
    # Normalized personal PPG
    scaler = MinMaxScaler()
    norm = scaler.fit_transform(PPG) * 1000
    # norm = scaler.fit_transform(PPG)
    
    # Split into per video
    for i in range(40):
        norm_video = norm[i*7680 : i*7680+7680]
        normalized.append(norm_video)

normalized = np.array(normalized)
normalized.shape
# Out:
# <ipython-input-5-e6cf46d087df>:33: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)
# (800,)

# %%
# window = 1280
timestep = 1280
segmented = []
valence_data = []
arousal_data = []

################################################
# for index in range(len(preprocessed) - timestep): 
#     segmented.append(preprocessed[index: index + timestep])
idx = 0
for PPG in normalized:
    for index in range(0, len(PPG) - timestep, 128):
        segmented.append(PPG[index : index + timestep,:])
        valence_data.append(Valence_data[idx])
        arousal_data.append(Arousal_data[idx])
    idx += 1
print(len(segmented))
# Out:
# 39200

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
from tensorflow import keras
from tensorflow.keras import layers, callbacks
# from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 2 GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10000)]) # limit in megabytes
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
train_x = segmented
train_valence = valence_data
train_arousal = arousal_data

# %%
x_train_data = np.array(train_x).astype(np.float32)
y_train_data = np.array(train_valence).astype(np.float32)

X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
Y_train = y_train_data.reshape((y_train_data.shape[0],1))

print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
# Out:
# X_train shape : (39200, 1280, 1), Y_train shape : (39200, 1)

# %%
# Set Hyperparameters of the model
learning_rate = 0.000001
epochs = 100
batch_size=128

# %%
from tensorflow.keras.layers import LSTM, GRU


# one GRU layers with three dense layers-> IT WORKS !
model = Sequential()
model.add(GRU(units=128,
              dropout=0.25,
              recurrent_dropout=0.25,
              return_sequences=False,
              input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(BatchNormalization())

# Dense net
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='BinaryClassification_Dense3-callback.h5', monitor='val_accuracy', save_best_only=True),
                tf.keras.callbacks.EarlyStopping(patience=10)]

model.compile(loss='binary_crossentropy', optimizer=Adam(lr=learning_rate), metrics=['acc'])
model.summary()
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 281,217
# Trainable params: 280,961
# Non-trainable params: 256
# _________________________________________________________________

# %%
history=model.fit(X_train,
                  Y_train,
                  epochs=epochs,
                  batch_size=batch_size,
                  validation_split=0.2,
                  callbacks=callback_list,
                  shuffle=True,
                  verbose=1)
# Out:
# Epoch 1/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7536 - acc: 0.5111WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2418s 10s/step - loss: 0.7536 - acc: 0.5111 - val_loss: 0.6938 - val_acc: 0.4777
# Epoch 2/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7363 - acc: 0.5142WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2410s 10s/step - loss: 0.7363 - acc: 0.5142 - val_loss: 0.6940 - val_acc: 0.4791
# Epoch 3/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7304 - acc: 0.5084WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2401s 10s/step - loss: 0.7304 - acc: 0.5084 - val_loss: 0.6936 - val_acc: 0.4782
# Epoch 4/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7307 - acc: 0.5028WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2408s 10s/step - loss: 0.7307 - acc: 0.5028 - val_loss: 0.6932 - val_acc: 0.4820
# Epoch 5/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7249 - acc: 0.5087WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2405s 10s/step - loss: 0.7249 - acc: 0.5087 - val_loss: 0.6927 - val_acc: 0.5130
# Epoch 6/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7247 - acc: 0.5066WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2406s 10s/step - loss: 0.7247 - acc: 0.5066 - val_loss: 0.6925 - val_acc: 0.5168
# Epoch 7/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7210 - acc: 0.5115WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2406s 10s/step - loss: 0.7210 - acc: 0.5115 - val_loss: 0.6918 - val_acc: 0.5427
# Epoch 8/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7226 - acc: 0.5083WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2413s 10s/step - loss: 0.7226 - acc: 0.5083 - val_loss: 0.6916 - val_acc: 0.5458
# Epoch 9/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7225 - acc: 0.5041WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2409s 10s/step - loss: 0.7225 - acc: 0.5041 - val_loss: 0.6911 - val_acc: 0.5477
# Epoch 10/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7196 - acc: 0.5083WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2406s 10s/step - loss: 0.7196 - acc: 0.5083 - val_loss: 0.6911 - val_acc: 0.5467
# Epoch 11/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7183 - acc: 0.5031WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2406s 10s/step - loss: 0.7183 - acc: 0.5031 - val_loss: 0.6909 - val_acc: 0.5452
# Epoch 12/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7186 - acc: 0.5102WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2408s 10s/step - loss: 0.7186 - acc: 0.5102 - val_loss: 0.6907 - val_acc: 0.5467
# Epoch 13/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7156 - acc: 0.5086WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2406s 10s/step - loss: 0.7156 - acc: 0.5086 - val_loss: 0.6909 - val_acc: 0.5425
# Epoch 14/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7180 - acc: 0.5029WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2410s 10s/step - loss: 0.7180 - acc: 0.5029 - val_loss: 0.6908 - val_acc: 0.5380
# Epoch 15/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7181 - acc: 0.5027WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2406s 10s/step - loss: 0.7181 - acc: 0.5027 - val_loss: 0.6906 - val_acc: 0.5402
# Epoch 16/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7151 - acc: 0.5093WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2409s 10s/step - loss: 0.7151 - acc: 0.5093 - val_loss: 0.6903 - val_acc: 0.5422
# Epoch 17/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7147 - acc: 0.5038WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2408s 10s/step - loss: 0.7147 - acc: 0.5038 - val_loss: 0.6901 - val_acc: 0.5432
# Epoch 18/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7128 - acc: 0.5137WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2412s 10s/step - loss: 0.7128 - acc: 0.5137 - val_loss: 0.6900 - val_acc: 0.5441
# Epoch 19/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7133 - acc: 0.5090WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2412s 10s/step - loss: 0.7133 - acc: 0.5090 - val_loss: 0.6898 - val_acc: 0.5449
# Epoch 20/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7140 - acc: 0.5074WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2418s 10s/step - loss: 0.7140 - acc: 0.5074 - val_loss: 0.6897 - val_acc: 0.5448
# Epoch 21/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7124 - acc: 0.5065WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2415s 10s/step - loss: 0.7124 - acc: 0.5065 - val_loss: 0.6895 - val_acc: 0.5446
# Epoch 22/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7084 - acc: 0.5143WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2413s 10s/step - loss: 0.7084 - acc: 0.5143 - val_loss: 0.6893 - val_acc: 0.5463
# Epoch 23/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7101 - acc: 0.5097WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2411s 10s/step - loss: 0.7101 - acc: 0.5097 - val_loss: 0.6891 - val_acc: 0.5463
# Epoch 24/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7094 - acc: 0.5127WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2411s 10s/step - loss: 0.7094 - acc: 0.5127 - val_loss: 0.6891 - val_acc: 0.5462
# Epoch 25/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7083 - acc: 0.5153WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2415s 10s/step - loss: 0.7083 - acc: 0.5153 - val_loss: 0.6891 - val_acc: 0.5478
# Epoch 26/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7073 - acc: 0.5164WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2415s 10s/step - loss: 0.7073 - acc: 0.5164 - val_loss: 0.6889 - val_acc: 0.5481
# Epoch 27/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7096 - acc: 0.5101WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2409s 10s/step - loss: 0.7096 - acc: 0.5101 - val_loss: 0.6888 - val_acc: 0.5471
# Epoch 28/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7077 - acc: 0.5130WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2413s 10s/step - loss: 0.7077 - acc: 0.5130 - val_loss: 0.6887 - val_acc: 0.5474
# Epoch 29/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7082 - acc: 0.5110WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2408s 10s/step - loss: 0.7082 - acc: 0.5110 - val_loss: 0.6886 - val_acc: 0.5503
# Epoch 30/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7071 - acc: 0.5103WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2411s 10s/step - loss: 0.7071 - acc: 0.5103 - val_loss: 0.6885 - val_acc: 0.5477
# Epoch 31/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7078 - acc: 0.5088WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2413s 10s/step - loss: 0.7078 - acc: 0.5088 - val_loss: 0.6885 - val_acc: 0.5499
# Epoch 32/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7070 - acc: 0.5108WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2414s 10s/step - loss: 0.7070 - acc: 0.5108 - val_loss: 0.6884 - val_acc: 0.5489
# Epoch 33/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7061 - acc: 0.5104WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2414s 10s/step - loss: 0.7061 - acc: 0.5104 - val_loss: 0.6883 - val_acc: 0.5497
# Epoch 34/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7066 - acc: 0.5102WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2417s 10s/step - loss: 0.7066 - acc: 0.5102 - val_loss: 0.6883 - val_acc: 0.5489
# Epoch 35/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7073 - acc: 0.5080WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2413s 10s/step - loss: 0.7073 - acc: 0.5080 - val_loss: 0.6884 - val_acc: 0.5499
# Epoch 36/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7054 - acc: 0.5138WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2416s 10s/step - loss: 0.7054 - acc: 0.5138 - val_loss: 0.6884 - val_acc: 0.5489
# Epoch 37/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7059 - acc: 0.5119WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2418s 10s/step - loss: 0.7059 - acc: 0.5119 - val_loss: 0.6884 - val_acc: 0.5486
# Epoch 38/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7030 - acc: 0.5176WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2418s 10s/step - loss: 0.7030 - acc: 0.5176 - val_loss: 0.6884 - val_acc: 0.5482
# Epoch 39/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7029 - acc: 0.5156WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2417s 10s/step - loss: 0.7029 - acc: 0.5156 - val_loss: 0.6885 - val_acc: 0.5487
# Epoch 40/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7041 - acc: 0.5122WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2418s 10s/step - loss: 0.7041 - acc: 0.5122 - val_loss: 0.6885 - val_acc: 0.5494
# Epoch 41/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7044 - acc: 0.5094WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2414s 10s/step - loss: 0.7044 - acc: 0.5094 - val_loss: 0.6883 - val_acc: 0.5477
# Epoch 42/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7028 - acc: 0.5165WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2418s 10s/step - loss: 0.7028 - acc: 0.5165 - val_loss: 0.6884 - val_acc: 0.5481
# Epoch 43/100
# 245/245 [==============================] - ETA: 0s - loss: 0.7021 - acc: 0.5153WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 245/245 [==============================] - 2414s 10s/step - loss: 0.7021 - acc: 0.5153 - val_loss: 0.6884 - val_acc: 0.5482

# %%
plt_performance(history,path='./plot_performance',filename='GRU_0527')

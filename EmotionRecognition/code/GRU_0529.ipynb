# %%
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from scipy.signal import find_peaks
from scipy import signal
from scipy.integrate import trapz
from scipy.interpolate import interp1d
import seaborn as sns
import heartpy as hp
import os
import pickle
import warnings
warnings.simplefilter('ignore', np.RankWarning)

# %%
def plt_performance(history, path='./', filename=''):
    epoch = list(range(0,len(history.history['loss'])))
    
    fig, (his_accuracy, his_loss) = plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)
    his_loss.plot(epoch, history.history['loss'], label='Training loss')
    his_loss.plot(epoch, history.history['val_loss'], label='Validation loss')
    his_loss.set_xlabel("Epochs", fontsize=14)
    his_loss.set_ylabel("Loss", fontsize=14)
    his_loss.set_title("Loss", fontsize=14)
    his_loss.legend(loc='best')
    
    his_accuracy.plot(epoch, history.history['accuracy'], label='Training accuracy')
    his_accuracy.plot(epoch, history.history['val_accuracy'], label='Validation accuracy')
    his_accuracy.set_xlabel("Epochs", fontsize=14)
    his_accuracy.set_ylabel("Accuracy", fontsize=14)
    his_accuracy.set_title("Accuracy", fontsize=14)
    his_accuracy.legend(loc='best')
    
    fig.tight_layout()
    if filename == '':
        plt.savefig(f'{path}/GRU/label_segmented/performance.png', bbox_inches='tight')
    else:
        plt.savefig(f'{path}/GRU/label_segmented/{filename}.png', bbox_inches='tight')
    plt.show()
    
"""
Pre-processing method
"""

def preprocessing1(PPG_data):
    """
    Fast Emotion Recognition reference
    """

    index = 0
    x = list(range(0,len(PPG_data[0])))
    
    for PPG in PPG_data:
        poly = np.polyfit(x, PPG, deg=50)
        polied = np.polyval(poly, x)
        detrended = PPG - polied
        PPG_data[index] = detrended
        index += 1
        
    return PPG_data


def preprocessing2(ppg_data, view = False, participant = ''):
    """
    Analysis PPG signal reference
    """
    
    # moving average function
    m_avg = lambda t, x, w : (np.asarray([t[i] for i in range(w, len(x) - w)]),
                          np.convolve(x, np.ones((2*w + 1, )) / (2*w + 1),
                                      mode = 'valid'))

    fs = len(ppg_data)/(60)  # sample rate

    # moving average
    w_size = int(fs*.5)  # width of moving window
    times = list(range(0,len(ppg_data)))
    mt, ms = m_avg(times, ppg_data, w_size)

    sign = (ppg_data[w_size:-w_size]-ms)

    analytical_signal = np.abs(signal.hilbert(sign))

    fs = len(sign) / (max(mt) - min(mt))
    w_size = int(fs)
    mt_new, mov_avg = m_avg(mt, analytical_signal, w_size)

    signal_pure = sign[w_size : -w_size] / mov_avg
    
    if view:
        plt.ioff()
        
        fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, ncols = 1, figsize = (10, 8), sharex=True)
        ax1.plot(times, ppg_data, "b-", label="Original")
        ax1.legend(loc='best')
        ax1.set_title("participants"+str(participant)+" Raw", fontsize=14)#, fontweight="bold")

        ax2.plot(mt, sign, 'r-', label="Pure signal")
        ax2.plot(mt_new, mov_avg, 'b-', label='Modulation', alpha=.5)
        ax2.legend(loc='best')
        ax2.set_title("Raw -> filtered", fontsize=14)#, fontweight="bold")

        ax3.plot(mt_new, signal_pure, "g-", label="Demodulated")
        ax3.set_xlim(0, mt[-1])
        ax3.set_title("Raw -> filtered -> demodulated", fontsize=14)#, fontweight="bold")

        ax3.set_xlabel("Time (sec)", fontsize=14) # common axis label
        ax3.legend(loc='best')

        fig.tight_layout()
        plt.savefig(f'./plot_img/{participant}.png', bbox_inches='tight')
        
    return signal_pure

    
def get_peaks(ppg_processed):
    diff_sig_2 = np.diff(ppg_processed) ## do
    peaks_2, _ = find_peaks(diff_sig_2, distance=100*(30/60), prominence=0.01)
    result = []
    peaks = []
    
    for i in range(len(peaks_2)):
        if diff_sig_2[peaks_2][i] > 40:
            result.append(peaks_2[i])
            peaks.append(diff_sig_2[peaks_2][i])
            
    return result, peaks, diff_sig_2

# %%
dir_list_ = os.listdir("./data")
dir_list_.sort()
count = 0
dir_list = []
for i in range(22):
    dir_list.append(dir_list_[i])
    
#### pop unavailable data
dir_list.pop(5)
dir_list.pop(2)

print(dir_list)
df_PPG = pd.DataFrame(columns=['participant','video_number','ppg','valence','arousal'])
Valence_data = []
Arousal_data = []
PPG_data = []

file_num = 0
for file in dir_list:
    dat_file = f'./data/{file}'
    with open(dat_file, 'rb') as f:
        Channel_data = pickle.load(f,encoding='latin1')
    data = Channel_data["data"]
    labels = Channel_data["labels"]
    for video_num in range(40):
        dataP = data[video_num,38]
        dataP = dataP[384:]
        
        label = labels[video_num]
        if label[0] < 5:
            Valence = 0
        if label[0] >= 5:
            Valence = 1
        if label[1] < 5:
            Arousal = 0
        if label[1] >= 5:
            Arousal = 1
        instance = [(file_num, video_num, dataP, Valence, Arousal)]
        new_instance = pd.DataFrame(instance, columns=['participant','video_number','ppg','valence','arousal'])
        df_PPG = pd.concat([df_PPG, new_instance], ignore_index = True)
        PPG_data.append(dataP)
        Valence_data.append(Valence)
        Arousal_data.append(Arousal)
    file_num += 1
    
PPG_shape = np.array(PPG_data)
PPG_shape.shape
# Out:
# ['s01.dat', 's02.dat', 's04.dat', 's05.dat', 's07.dat', 's08.dat', 's09.dat', 's10.dat', 's11.dat', 's12.dat', 's13.dat', 's14.dat', 's15.dat', 's16.dat', 's17.dat', 's18.dat', 's19.dat', 's20.dat', 's21.dat', 's22.dat']
# (800, 7680)

# %% [markdown]
# ## Preprocessing method 1, 2

# %%
PPG_data = df_PPG['ppg']

preprocessed1 = preprocessing1(PPG_data)
# Out:
# /home/sselab/anaconda3/envs/EmotionRecognition/lib/python3.8/site-packages/numpy/lib/polynomial.py:627: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/sselab/anaconda3/envs/EmotionRecognition/lib/python3.8/site-packages/numpy/core/_methods.py:47: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
preprocessed2 = []

for PPG in PPG_data:
    preprocessed_d = preprocessing2(PPG,view=False)
    preprocessed2.append(preprocessed_d)

preprocessed2 = np.array(preprocessed2)

# %% [markdown]
# ## Normalization * 1000 or not

# %%
# Concatenate PPG data of each person to use min-max normalization method 
def normalizing(preprocessed, scale=False):
    i = 1
    new_PPG = []
    tmp_PPG = np.empty(0)
    for PPG in preprocessed:
        if i % 40 != 0:
            tmp_PPG = np.concatenate([tmp_PPG, PPG])
        else:
            tmp_PPG = np.concatenate([tmp_PPG, PPG])
            new_PPG.append(tmp_PPG)
            tmp_PPG = np.empty(0)
        i += 1


    # Normalize personal PPG data and Split into per video
    new_PPG = np.array(new_PPG)
    new_PPG.shape[0]
    new_PPG = new_PPG.reshape(new_PPG.shape[0],new_PPG.shape[1],1)

    normalized = []
    
    if scale==True:
        for PPG in new_PPG:
            # Normalized personal PPG
            scaler = MinMaxScaler()
            norm = scaler.fit_transform(PPG) * 1000

            # Split into per video
            for i in range(40):
                norm_video = norm[i*7680 : i*7680+7680]
                normalized.append(norm_video)
    else:
        for PPG in new_PPG:
            # Normalized personal PPG
            scaler = MinMaxScaler()
            norm = scaler.fit_transform(PPG)

            # Split into per video
            for i in range(40):
                norm_video = norm[i*7680 : i*7680+7680]
                normalized.append(norm_video)
                

    normalized = np.array(normalized)
    print(normalized.shape)
    
    return normalized

# %%
normalized1 = normalizing(preprocessed1, scale=True)
normalized2 = normalizing(preprocessed1, scale=False)
normalized3 = normalizing(preprocessed2, scale=True)
normalized4 = normalizing(preprocessed2, scale=False)
# Out:
# (800, 7680, 1)
# (800, 7680, 1)
# (800,)
# (800,)
# <ipython-input-6-4530231ba5fc>:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)
# <ipython-input-6-4530231ba5fc>:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)

# %% [markdown]
# ## segmentation

# %%
def segmentate(normalized, Arousal_data, Valence_data, timestep=1280, stride=128):
    segmented = []
    valence_data = []
    arousal_data = []

    idx = 0
    for PPG in normalized:
        for index in range(0, len(PPG) - timestep, stride):
            segmented.append(PPG[index : index + timestep,:])
            #############
        valence_data.append(Valence_data[idx])
        arousal_data.append(Arousal_data[idx])
        idx += 1
    print(len(segmented))
    
    return segmented, valence_data, arousal_data

# %%
timestep = 1280
stride = 128

segmented1, valence_data, arousal_data = segmentate(normalized1, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 with scale
segmented2, valence_data, arousal_data = segmentate(normalized2, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 without scale
segmented3, valence_data, arousal_data = segmentate(normalized3, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 with scale
segmented4, valence_data, arousal_data = segmentate(normalized4, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 without scale
# Out:
# 40000
# 40000
# 39200
# 39200

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
from tensorflow import keras
from tensorflow.keras import layers, callbacks
# from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM, GRU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 2 GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10000)]) # limit in megabytes
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
def setTraindata(segmented, valence_data, arousal_data, type='valence'):
    if type == 'valence':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
        Y_train = y_train_data.reshape((y_train_data.shape[0],1))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    elif type == 'arousal':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
        Y_train = y_train_data.reshape((y_train_data.shape[0],1))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    else:
        print("type error")
        
    return X_train, Y_train

# %%
X_train1, Y_train = setTraindata(segmented1, valence_data, arousal_data)
X_train2, Y_train = setTraindata(segmented2, valence_data, arousal_data)
X_train3, Y_train = setTraindata(segmented3, valence_data, arousal_data)
X_train4, Y_train = setTraindata(segmented4, valence_data, arousal_data)
# Out:
# X_train shape : (40000, 1280, 1), Y_train shape : (800, 1)
# X_train shape : (40000, 1280, 1), Y_train shape : (800, 1)
# X_train shape : (39200, 1280, 1), Y_train shape : (800, 1)
# X_train shape : (39200, 1280, 1), Y_train shape : (800, 1)

# %%
def create_model1(learning_rate, X_train):

    model = Sequential()
    model.add(GRU(units=128,
                  dropout=0.3,
                  # recurrent_dropout=0.25,
                  return_sequences=False,
                  input_shape=[None,X_train.shape[2]]))
    model.add(BatchNormalization())

    # Dense net
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))

    # callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='BinaryClassification_Dense3-callback.h5', monitor='val_accuracy', save_best_only=True),
    #                 tf.keras.callbacks.EarlyStopping(patience=10)]

    model.compile(loss='binary_crossentropy', optimizer=SGD(lr=learning_rate), metrics=['accuracy'])
    model.summary()


#     from tensorflow.keras.layers import Activation
#     model = Sequential()
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2]),return_sequences=True))
#     model.add(Dropout(0.4))
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2])))
#     model.add(Dropout(0.3))
#     model.add(Dense(100))
#     model.add(Dense(1))
#     model.add(Activation('sigmoid'))
#     model.summary()

#     from tensorflow.keras.optimizers import Adam
#     model.compile(optimizer=Adam(lr=0.01,),loss='binary_crossentropy',metrics=['acc'])
    
    return model

# %%
callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='BinaryClassification_Dense3-callback.h5', monitor='val_accuracy', save_best_only=True),
                    tf.keras.callbacks.EarlyStopping(patience=3)]

# %%
def runModels(tried_num,lr,X_train1,X_train2,X_train3,X_train4,Y_train):
    print("***********************************")
    print("model_1 : preprocessing1 with scale")
    print("***********************************")
    model1 = create_model1(learning_rate,X_train1)

    history1=model1.fit(X_train1,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)
    file_name = f'GRU_0529_model_p1ws_lr={lr}_({tried_num})'
    plt_performance(history1,path='./plot_performance',filename=file_name)
    model1.save(f"./models/{file_name}.h5")
    keras.backend.clear_session()
    
    print("***********************************")
    print("model_2 : preprocessing1 without scale")
    print("***********************************")
    model2 = create_model1(learning_rate,X_train2)

    history2=model2.fit(X_train2,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)

    file_name = f'GRU_0529_modelp1xs_lr={lr}_({tried_num})'
    plt_performance(history2,path='./plot_performance',filename=file_name)
    model2.save(f"./models/{file_name}.h5")
    keras.backend.clear_session()
    
    
    print("***********************************")
    print("model_3 : preprocessing2 with scale")
    print("***********************************")
    model3 = create_model1(learning_rate,X_train3)

    history3=model3.fit(X_train3,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)

    
    file_name = f'GRU_0529_modelp2ws_lr={lr}_({tried_num})'
    plt_performance(history3,path='./plot_performance',filename=file_name)
    model3.save(f"./models/{file_name}.h5")
    keras.backend.clear_session()

    
    print("***********************************")
    print("model_4 : preprocessing2 without scale")
    print("***********************************")
    model4 = create_model1(learning_rate,X_train4)

    history4=model4.fit(X_train4,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)

    
    file_name = f'GRU_0529_modelp2xs_lr={lr}_({tried_num})'
    plt_performance(history4,path='./plot_performance',filename=file_name)
    model4.save(f"./models/{file_name}.h5")
    keras.backend.clear_session()

# %%
# Set Hyperparameters of the model
epochs = 5
batch_size=128
# learning_rate = 0.0000001
learning_rates = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
# learning_rates = [0.00001]
index = 0
for learning_rate in learning_rates:
    print(learning_rate)
    tried_num = index
    runModels(tried_num,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train)
    index += 1
# Out:
# 0.01
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 17s 70ms/step - loss: 0.1143 - accuracy: 0.9776 - val_loss: 0.0892 - val_accuracy: 1.0000
# Epoch 2/5
# 250/250 [==============================] - 18s 74ms/step - loss: 0.0864 - accuracy: 0.9862 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 3/5
# 250/250 [==============================] - 18s 71ms/step - loss: 0.0834 - accuracy: 0.9864 - val_loss: 6.4963e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 250/250 [==============================] - 18s 72ms/step - loss: 0.0847 - accuracy: 0.9865 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 5/5
# 250/250 [==============================] - 18s 71ms/step - loss: 0.0795 - accuracy: 0.9865 - val_loss: 0.0014 - val_accuracy: 1.0000
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 18s 72ms/step - loss: 0.1101 - accuracy: 0.9783 - val_loss: 0.0814 - val_accuracy: 1.0000
# Epoch 2/5
# 250/250 [==============================] - 18s 73ms/step - loss: 0.0813 - accuracy: 0.9863 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 3/5
# 250/250 [==============================] - 18s 71ms/step - loss: 0.0789 - accuracy: 0.9865 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 4/5
# 250/250 [==============================] - 19s 75ms/step - loss: 0.0781 - accuracy: 0.9865 - val_loss: 0.0143 - val_accuracy: 1.0000
# Epoch 5/5
# 250/250 [==============================] - 19s 75ms/step - loss: 0.0772 - accuracy: 0.9865 - val_loss: 0.0139 - val_accuracy: 1.0000
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 18s 75ms/step - loss: 0.1378 - accuracy: 0.9637 - val_loss: 0.0226 - val_accuracy: 1.0000
# Epoch 2/5
# 245/245 [==============================] - 19s 76ms/step - loss: 0.0862 - accuracy: 0.9860 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 3/5
# 245/245 [==============================] - 19s 76ms/step - loss: 0.0839 - accuracy: 0.9862 - val_loss: 7.8554e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 245/245 [==============================] - 19s 76ms/step - loss: 0.0816 - accuracy: 0.9864 - val_loss: 4.4399e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 245/245 [==============================] - 19s 77ms/step - loss: 0.0828 - accuracy: 0.9861 - val_loss: 8.7323e-04 - val_accuracy: 1.0000
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.1164 - accuracy: 0.9763 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 2/5
# 245/245 [==============================] - 20s 81ms/step - loss: 0.0855 - accuracy: 0.9863 - val_loss: 0.0201 - val_accuracy: 1.0000
# Epoch 3/5
# 245/245 [==============================] - 20s 83ms/step - loss: 0.0850 - accuracy: 0.9864 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 4/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.0832 - accuracy: 0.9863 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 5/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.0821 - accuracy: 0.9863 - val_loss: 0.0168 - val_accuracy: 1.0000
# 0.001
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 20s 78ms/step - loss: 0.2358 - accuracy: 0.9282 - val_loss: 0.1400 - val_accuracy: 1.0000
# Epoch 2/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.1182 - accuracy: 0.9811 - val_loss: 0.0372 - val_accuracy: 1.0000
# Epoch 3/5
# 250/250 [==============================] - 20s 78ms/step - loss: 0.1033 - accuracy: 0.9839 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 4/5
# 250/250 [==============================] - 20s 78ms/step - loss: 0.0947 - accuracy: 0.9849 - val_loss: 6.9675e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.0919 - accuracy: 0.9847 - val_loss: 0.0013 - val_accuracy: 1.0000
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 21s 84ms/step - loss: 0.3219 - accuracy: 0.8784 - val_loss: 0.1847 - val_accuracy: 1.0000
# Epoch 2/5
# 250/250 [==============================] - 20s 80ms/step - loss: 0.1215 - accuracy: 0.9816 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 3/5
# 250/250 [==============================] - 20s 80ms/step - loss: 0.0988 - accuracy: 0.9849 - val_loss: 0.0231 - val_accuracy: 1.0000
# Epoch 4/5
# 250/250 [==============================] - 21s 85ms/step - loss: 0.0910 - accuracy: 0.9857 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 5/5
# 250/250 [==============================] - 20s 80ms/step - loss: 0.0866 - accuracy: 0.9859 - val_loss: 0.0144 - val_accuracy: 1.0000
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 21s 84ms/step - loss: 0.3820 - accuracy: 0.8447 - val_loss: 0.1896 - val_accuracy: 1.0000
# Epoch 2/5
# 245/245 [==============================] - 19s 79ms/step - loss: 0.1333 - accuracy: 0.9772 - val_loss: 0.0353 - val_accuracy: 1.0000
# Epoch 3/5
# 245/245 [==============================] - 19s 79ms/step - loss: 0.1045 - accuracy: 0.9829 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 4/5
# 245/245 [==============================] - 20s 81ms/step - loss: 0.0956 - accuracy: 0.9847 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 5/5
# 245/245 [==============================] - 20s 80ms/step - loss: 0.0937 - accuracy: 0.9853 - val_loss: 0.0023 - val_accuracy: 1.0000
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.2283 - accuracy: 0.9345 - val_loss: 0.1770 - val_accuracy: 1.0000
# Epoch 2/5
# 245/245 [==============================] - 20s 81ms/step - loss: 0.1134 - accuracy: 0.9837 - val_loss: 0.0683 - val_accuracy: 1.0000
# Epoch 3/5
# 245/245 [==============================] - 21s 87ms/step - loss: 0.0971 - accuracy: 0.9851 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 4/5
# 245/245 [==============================] - 20s 81ms/step - loss: 0.0916 - accuracy: 0.9856 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 5/5
# 245/245 [==============================] - 20s 80ms/step - loss: 0.0871 - accuracy: 0.9859 - val_loss: 0.0229 - val_accuracy: 1.0000
# 0.0001
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 20s 79ms/step - loss: 0.4166 - accuracy: 0.8394 - val_loss: 0.3037 - val_accuracy: 0.9835
# Epoch 2/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.3127 - accuracy: 0.9025 - val_loss: 0.3670 - val_accuracy: 0.9135
# Epoch 3/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.2601 - accuracy: 0.9333 - val_loss: 0.4601 - val_accuracy: 0.9281
# Epoch 4/5
# 250/250 [==============================] - 20s 78ms/step - loss: 0.2232 - accuracy: 0.9499 - val_loss: 0.5823 - val_accuracy: 0.9231
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.5602 - accuracy: 0.7113 - val_loss: 0.4557 - val_accuracy: 1.0000
# Epoch 2/5
# 250/250 [==============================] - 19s 77ms/step - loss: 0.4044 - accuracy: 0.8393 - val_loss: 0.3574 - val_accuracy: 1.0000
# Epoch 3/5
# 250/250 [==============================] - 20s 80ms/step - loss: 0.3190 - accuracy: 0.9017 - val_loss: 0.2416 - val_accuracy: 1.0000
# Epoch 4/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.2670 - accuracy: 0.9333 - val_loss: 0.1964 - val_accuracy: 1.0000
# Epoch 5/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.2312 - accuracy: 0.9503 - val_loss: 0.1687 - val_accuracy: 1.0000
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.8228 - accuracy: 0.5430 - val_loss: 0.7266 - val_accuracy: 0.2629
# Epoch 2/5
# 245/245 [==============================] - 19s 79ms/step - loss: 0.5781 - accuracy: 0.7210 - val_loss: 0.8697 - val_accuracy: 0.2513
# Epoch 3/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.4357 - accuracy: 0.8271 - val_loss: 0.2548 - val_accuracy: 0.9838
# Epoch 4/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.3484 - accuracy: 0.8850 - val_loss: 0.0694 - val_accuracy: 1.0000
# Epoch 5/5
# 245/245 [==============================] - 19s 77ms/step - loss: 0.2886 - accuracy: 0.9200 - val_loss: 0.0297 - val_accuracy: 1.0000
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 21s 86ms/step - loss: 0.8260 - accuracy: 0.5438 - val_loss: 0.6058 - val_accuracy: 0.9812
# Epoch 2/5
# 245/245 [==============================] - 21s 85ms/step - loss: 0.5238 - accuracy: 0.7413 - val_loss: 0.3718 - val_accuracy: 1.0000
# Epoch 3/5
# 245/245 [==============================] - 20s 82ms/step - loss: 0.3945 - accuracy: 0.8338 - val_loss: 0.2322 - val_accuracy: 1.0000
# Epoch 4/5
# 245/245 [==============================] - 19s 79ms/step - loss: 0.3204 - accuracy: 0.8850 - val_loss: 0.1620 - val_accuracy: 1.0000
# Epoch 5/5
# 245/245 [==============================] - 20s 81ms/step - loss: 0.2673 - accuracy: 0.9159 - val_loss: 0.1360 - val_accuracy: 1.0000
# 1e-05
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 21s 82ms/step - loss: 0.7548 - accuracy: 0.5696 - val_loss: 0.5768 - val_accuracy: 0.7545
# Epoch 2/5
# 250/250 [==============================] - 21s 83ms/step - loss: 0.7102 - accuracy: 0.6018 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 3/5
# 250/250 [==============================] - 20s 81ms/step - loss: 0.6778 - accuracy: 0.6262 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 4/5
# 250/250 [==============================] - 20s 79ms/step - loss: 0.6388 - accuracy: 0.6473 - val_loss: 0.0260 - val_accuracy: 1.0000
# Epoch 5/5
# 250/250 [==============================] - 21s 82ms/step - loss: 0.6079 - accuracy: 0.6665 - val_loss: 0.0274 - val_accuracy: 1.0000
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 20s 82ms/step - loss: 1.1568 - accuracy: 0.3456 - val_loss: 0.7028 - val_accuracy: 0.4482
# Epoch 2/5
# 250/250 [==============================] - 20s 80ms/step - loss: 1.0877 - accuracy: 0.3748 - val_loss: 0.6962 - val_accuracy: 0.5559
# Epoch 3/5
# 250/250 [==============================] - 20s 79ms/step - loss: 1.0098 - accuracy: 0.4119 - val_loss: 0.7041 - val_accuracy: 0.4299
# Epoch 4/5
# 250/250 [==============================] - 21s 84ms/step - loss: 0.9627 - accuracy: 0.4365 - val_loss: 0.6610 - val_accuracy: 0.5345
# Epoch 5/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.9094 - accuracy: 0.4699 - val_loss: 0.6242 - val_accuracy: 0.6766
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 78ms/step - loss: 1.2794 - accuracy: 0.3168 - val_loss: 1.2817 - val_accuracy: 5.1020e-04
# Epoch 2/5
# 245/245 [==============================] - 19s 79ms/step - loss: 1.2199 - accuracy: 0.3488 - val_loss: 4.4313 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 245/245 [==============================] - 21s 84ms/step - loss: 1.1643 - accuracy: 0.3777 - val_loss: 4.0402 - val_accuracy: 1.2755e-04
# Epoch 4/5
# 245/245 [==============================] - 19s 78ms/step - loss: 1.1108 - accuracy: 0.4029 - val_loss: 3.5708 - val_accuracy: 1.2755e-04
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 78ms/step - loss: 1.3326 - accuracy: 0.2547 - val_loss: 0.8973 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 245/245 [==============================] - 19s 78ms/step - loss: 1.2489 - accuracy: 0.2817 - val_loss: 0.9546 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 245/245 [==============================] - 20s 81ms/step - loss: 1.1767 - accuracy: 0.3169 - val_loss: 0.9125 - val_accuracy: 0.0969
# Epoch 4/5
# 245/245 [==============================] - 20s 82ms/step - loss: 1.1036 - accuracy: 0.3531 - val_loss: 0.8734 - val_accuracy: 0.0906
# Epoch 5/5
# 245/245 [==============================] - 20s 81ms/step - loss: 1.0422 - accuracy: 0.3808 - val_loss: 0.8201 - val_accuracy: 0.2429
# 1e-06
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 21s 86ms/step - loss: 0.6585 - accuracy: 0.6473 - val_loss: 0.4551 - val_accuracy: 0.9998
# Epoch 2/5
# 250/250 [==============================] - 20s 78ms/step - loss: 0.6492 - accuracy: 0.6559 - val_loss: 0.0896 - val_accuracy: 0.9843
# Epoch 3/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.6508 - accuracy: 0.6562 - val_loss: 0.2729 - val_accuracy: 0.9144
# Epoch 4/5
# 250/250 [==============================] - 19s 78ms/step - loss: 0.6358 - accuracy: 0.6653 - val_loss: 0.3177 - val_accuracy: 0.9110
# Epoch 5/5
# 250/250 [==============================] - 20s 79ms/step - loss: 0.6372 - accuracy: 0.6679 - val_loss: 0.3247 - val_accuracy: 0.9133
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 250/250 [==============================] - 19s 77ms/step - loss: 1.4008 - accuracy: 0.2218 - val_loss: 0.9306 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 250/250 [==============================] - 19s 77ms/step - loss: 1.3899 - accuracy: 0.2220 - val_loss: 0.9792 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 250/250 [==============================] - 19s 78ms/step - loss: 1.3849 - accuracy: 0.2262 - val_loss: 1.0044 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 250/250 [==============================] - 19s 78ms/step - loss: 1.3723 - accuracy: 0.2271 - val_loss: 1.0147 - val_accuracy: 0.0000e+00
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.9889 - accuracy: 0.4783 - val_loss: 0.9401 - val_accuracy: 0.2501
# Epoch 2/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.9820 - accuracy: 0.4878 - val_loss: 1.1403 - val_accuracy: 0.2503
# Epoch 3/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.9756 - accuracy: 0.4883 - val_loss: 1.4503 - val_accuracy: 0.3091
# Epoch 4/5
# 245/245 [==============================] - 19s 78ms/step - loss: 0.9635 - accuracy: 0.4961 - val_loss: 1.5940 - val_accuracy: 0.2381
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/5
# 245/245 [==============================] - 19s 77ms/step - loss: 0.7269 - accuracy: 0.5975 - val_loss: 0.5797 - val_accuracy: 0.8469
# Epoch 2/5
# 245/245 [==============================] - 19s 77ms/step - loss: 0.7191 - accuracy: 0.6039 - val_loss: 0.5756 - val_accuracy: 0.6946
# Epoch 3/5
# 245/245 [==============================] - 19s 77ms/step - loss: 0.7140 - accuracy: 0.6085 - val_loss: 0.5835 - val_accuracy: 0.6811
# Epoch 4/5
# 245/245 [==============================] - 23s 93ms/step - loss: 0.7152 - accuracy: 0.6052 - val_loss: 0.5664 - val_accuracy: 0.6867
# Epoch 5/5
# 245/245 [==============================] - 19s 77ms/step - loss: 0.7070 - accuracy: 0.6112 - val_loss: 0.5620 - val_accuracy: 0.6884

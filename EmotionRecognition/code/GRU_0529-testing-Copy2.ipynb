# %%
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from scipy.signal import find_peaks
from scipy import signal
from scipy.integrate import trapz
from scipy.interpolate import interp1d
import seaborn as sns
import heartpy as hp
import os
import pickle
import warnings
warnings.simplefilter('ignore', np.RankWarning)

# %%
def plt_performance(history, path='./', filename=''):
    epoch = list(range(0,len(history.history['loss'])))
    
    fig, (his_accuracy, his_loss) = plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)
    his_loss.plot(epoch, history.history['loss'], label='Training loss')
    his_loss.plot(epoch, history.history['val_loss'], label='Validation loss')
    his_loss.set_xlabel("Epochs", fontsize=14)
    his_loss.set_ylabel("Loss", fontsize=14)
    his_loss.set_title("Loss", fontsize=14)
    his_loss.legend(loc='best')
    
    his_accuracy.plot(epoch, history.history['accuracy'], label='Training accuracy')
    his_accuracy.plot(epoch, history.history['val_accuracy'], label='Validation accuracy')
    his_accuracy.set_xlabel("Epochs", fontsize=14)
    his_accuracy.set_ylabel("Accuracy", fontsize=14)
    his_accuracy.set_title("Accuracy", fontsize=14)
    his_accuracy.legend(loc='best')
    
    fig.tight_layout()
    if filename == '':
        plt.savefig(f'{path}/GRU/performance.png', bbox_inches='tight')
    else:
        plt.savefig(f'{path}/GRU/{filename}.png', bbox_inches='tight')
    plt.show()
    
"""
Pre-processing method
"""

def preprocessing1(PPG_data):
    """
    Fast Emotion Recognition reference
    """

    index = 0
    x = list(range(0,len(PPG_data[0])))
    
    for PPG in PPG_data:
        poly = np.polyfit(x, PPG, deg=50)
        polied = np.polyval(poly, x)
        detrended = PPG - polied
        PPG_data[index] = detrended
        index += 1
        
    return PPG_data


def preprocessing2(ppg_data, view = False, participant = ''):
    """
    Analysis PPG signal reference
    """
    
    # moving average function
    m_avg = lambda t, x, w : (np.asarray([t[i] for i in range(w, len(x) - w)]),
                          np.convolve(x, np.ones((2*w + 1, )) / (2*w + 1),
                                      mode = 'valid'))

    fs = len(ppg_data)/(60)  # sample rate

    # moving average
    w_size = int(fs*.5)  # width of moving window
    times = list(range(0,len(ppg_data)))
    mt, ms = m_avg(times, ppg_data, w_size)

    sign = (ppg_data[w_size:-w_size]-ms)

    analytical_signal = np.abs(signal.hilbert(sign))

    fs = len(sign) / (max(mt) - min(mt))
    w_size = int(fs)
    mt_new, mov_avg = m_avg(mt, analytical_signal, w_size)

    signal_pure = sign[w_size : -w_size] / mov_avg
    
    if view:
        plt.ioff()
        
        fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, ncols = 1, figsize = (10, 8), sharex=True)
        ax1.plot(times, ppg_data, "b-", label="Original")
        ax1.legend(loc='best')
        ax1.set_title("participants"+str(participant)+" Raw", fontsize=14)#, fontweight="bold")

        ax2.plot(mt, sign, 'r-', label="Pure signal")
        ax2.plot(mt_new, mov_avg, 'b-', label='Modulation', alpha=.5)
        ax2.legend(loc='best')
        ax2.set_title("Raw -> filtered", fontsize=14)#, fontweight="bold")

        ax3.plot(mt_new, signal_pure, "g-", label="Demodulated")
        ax3.set_xlim(0, mt[-1])
        ax3.set_title("Raw -> filtered -> demodulated", fontsize=14)#, fontweight="bold")

        ax3.set_xlabel("Time (sec)", fontsize=14) # common axis label
        ax3.legend(loc='best')

        fig.tight_layout()
        plt.savefig(f'./plot_img/{participant}.png', bbox_inches='tight')
        
    return signal_pure

    
def get_peaks(ppg_processed):
    diff_sig_2 = np.diff(ppg_processed) ## do
    peaks_2, _ = find_peaks(diff_sig_2, distance=100*(30/60), prominence=0.01)
    result = []
    peaks = []
    
    for i in range(len(peaks_2)):
        if diff_sig_2[peaks_2][i] > 40:
            result.append(peaks_2[i])
            peaks.append(diff_sig_2[peaks_2][i])
            
    return result, peaks, diff_sig_2

# %%
dir_list_ = os.listdir("./data")
dir_list_.sort()
count = 0
dir_list = []
for i in range(22):
    dir_list.append(dir_list_[i])
    
#### pop unavailable data
dir_list.pop(5)
dir_list.pop(2)

print(dir_list)
df_PPG = pd.DataFrame(columns=['participant','video_number','ppg','valence','arousal'])
Valence_data = []
Arousal_data = []
PPG_data = []
dir_list = dir_list[:1]

file_num = 0
for file in dir_list:
    dat_file = f'./data/{file}'
    with open(dat_file, 'rb') as f:
        Channel_data = pickle.load(f,encoding='latin1')
    data = Channel_data["data"]
    labels = Channel_data["labels"]
    for video_num in range(40):
        dataP = data[video_num,38]
        dataP = dataP[384:]
        
        label = labels[video_num]
        if label[0] < 5:
            Valence = 0
        if label[0] >= 5:
            Valence = 1
        if label[1] < 5:
            Arousal = 0
        if label[1] >= 5:
            Arousal = 1
        instance = [(file_num, video_num, dataP, Valence, Arousal)]
        new_instance = pd.DataFrame(instance, columns=['participant','video_number','ppg','valence','arousal'])
        df_PPG = pd.concat([df_PPG, new_instance], ignore_index = True)
        PPG_data.append(dataP)
        Valence_data.append(Valence)
        Arousal_data.append(Arousal)
    file_num += 1
    
PPG_shape = np.array(PPG_data)
PPG_shape.shape
# Out:
# ['s01.dat', 's02.dat', 's04.dat', 's05.dat', 's07.dat', 's08.dat', 's09.dat', 's10.dat', 's11.dat', 's12.dat', 's13.dat', 's14.dat', 's15.dat', 's16.dat', 's17.dat', 's18.dat', 's19.dat', 's20.dat', 's21.dat', 's22.dat']
# (40, 7680)

# %%
# Concatenate PPG data of each person to use min-max normalization method 
def normalizing(preprocessed, scale=False):
    i = 1
    new_PPG = []
    tmp_PPG = np.empty(0)
    for PPG in preprocessed:
        if i % 40 != 0:
            tmp_PPG = np.concatenate([tmp_PPG, PPG])
        else:
            tmp_PPG = np.concatenate([tmp_PPG, PPG])
            new_PPG.append(tmp_PPG)
            tmp_PPG = np.empty(0)
        i += 1


    # Normalize personal PPG data and Split into per video
    new_PPG = np.array(new_PPG)
    new_PPG.shape[0]
    new_PPG = new_PPG.reshape(new_PPG.shape[0],new_PPG.shape[1],1)

    normalized = []
    
    if scale==True:
        for PPG in new_PPG:
            # Normalized personal PPG
            scaler = MinMaxScaler()
            norm = scaler.fit_transform(PPG) * 1000

            # Split into per video
            for i in range(40):
                norm_video = norm[i*7680 : i*7680+7680]
                normalized.append(norm_video)
    else:
        for PPG in new_PPG:
            # Normalized personal PPG
            scaler = MinMaxScaler()
            norm = scaler.fit_transform(PPG)

            # Split into per video
            for i in range(40):
                norm_video = norm[i*7680 : i*7680+7680]
                normalized.append(norm_video)
                

    normalized = np.array(normalized)
    print(normalized.shape)
    
    return normalized


def segmentate(normalized, Arousal_data, Valence_data, timestep=1280, stride=128):
    segmented = []
    valence_data = []
    arousal_data = []

    idx = 0
    for PPG in normalized:
        for index in range(0, len(PPG) - timestep, stride):
            segmented.append(PPG[index : index + timestep,:])
            #############
        valence_data.append(Valence_data[idx])
        arousal_data.append(Arousal_data[idx])
        idx += 1
    print(len(segmented))
    
    return segmented, valence_data, arousal_data

# %%
print("Valence label 0 : ",Valence_data.count(0))
print("Valence label 1 : ",Valence_data.count(1))

print("Arousal label 0 : ",Arousal_data.count(0))
print("Arousal label 1 : ",Arousal_data.count(1))
# Out:
# Valence label 0 :  21
# Valence label 1 :  19
# Arousal label 0 :  16
# Arousal label 1 :  24

# %% [markdown]
# ## Preprocessing method 1, 2

# %%
PPG_data = df_PPG['ppg']

preprocessed1 = preprocessing1(PPG_data)
# Out:
# /home/sselab/anaconda3/envs/EmotionRecognition/lib/python3.8/site-packages/numpy/lib/polynomial.py:627: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/sselab/anaconda3/envs/EmotionRecognition/lib/python3.8/site-packages/numpy/core/_methods.py:47: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
preprocessed2 = []

for PPG in PPG_data:
    preprocessed_d = preprocessing2(PPG,view=False)
    preprocessed2.append(preprocessed_d)

preprocessed2 = np.array(preprocessed2)

# %% [markdown]
# ## Normalization * 1000 or not

# %%
normalized1 = normalizing(preprocessed1, scale=True)
normalized2 = normalizing(preprocessed1, scale=False)
normalized3 = normalizing(preprocessed2, scale=True)
normalized4 = normalizing(preprocessed2, scale=False)
# Out:
# (40, 7680, 1)
# (40, 7680, 1)
# (40,)
# (40,)
# <ipython-input-4-eb8a6bbff4cc>:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)
# <ipython-input-4-eb8a6bbff4cc>:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)

# %% [markdown]
# ## segmentation

# %%
timestep = 1280
stride = 2
# normalized1 = [normalized1[0]]
# normalized2 = [normalized2[0]]
# normalized3 = [normalized3[0]]
# normalized4 = [normalized4[0]]
segmented1, valence_data, arousal_data = segmentate(normalized1, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 with scale
segmented2, valence_data, arousal_data = segmentate(normalized2, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 without scale
segmented3, valence_data, arousal_data = segmentate(normalized3, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 with scale
segmented4, valence_data, arousal_data = segmentate(normalized4, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 without scale
# Out:
# 128000
# 128000
# 125400
# 125400

# %%
times = list(range(0,len(segmented1[0])))
plt.plot(times,segmented1[0])
plt.plot(times,segmented3[0])

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
from tensorflow import keras
from tensorflow.keras import layers, callbacks
# from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM, GRU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 2 GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=9000)]) # limit in megabytes
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
def setTraindata(segmented, valence_data, arousal_data, type='valence'):
    if type == 'valence':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1]))
        Y_train = y_train_data.reshape((y_train_data.shape[0],))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    elif type == 'arousal':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1]))
        Y_train = y_train_data.reshape((y_train_data.shape[0],))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    else:
        print("type error")
        
    return X_train, Y_train

# %%
X_train1, Y_train = setTraindata(segmented1, valence_data, arousal_data)
X_train2, Y_train = setTraindata(segmented2, valence_data, arousal_data)
X_train3, Y_train = setTraindata(segmented3, valence_data, arousal_data)
X_train4, Y_train = setTraindata(segmented4, valence_data, arousal_data)
# Out:
# X_train shape : (128000, 1280), Y_train shape : (40,)
# X_train shape : (128000, 1280), Y_train shape : (40,)
# X_train shape : (125400, 1280), Y_train shape : (40,)
# X_train shape : (125400, 1280), Y_train shape : (40,)

# %%
def create_model1(learning_rate, X_train):

    model = Sequential()
    model.add(GRU(units=128,
                  dropout=0.3,
                  # recurrent_dropout=0.25,
                  return_sequences=False,
                  recurrent_regularizer='l2',
                  # input_shape=[X_train.shape[1],X_train.shape[2]]))
                  input_shape=[X_train.shape[1],1]))
    model.add(BatchNormalization())

    # Dense net
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))

    # callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='BinaryClassification_Dense3-callback.h5', monitor='val_accuracy', save_best_only=True),
    #                 tf.keras.callbacks.EarlyStopping(patience=10)]

    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=learning_rate), metrics=['accuracy'])
    model.summary()


#     from tensorflow.keras.layers import Activation
#     model = Sequential()
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2]),return_sequences=True))
#     model.add(Dropout(0.4))
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2])))
#     model.add(Dropout(0.3))
#     model.add(Dense(100))
#     model.add(Dense(1))
#     model.add(Activation('sigmoid'))
#     model.summary()

#     from tensorflow.keras.optimizers import Adam
#     model.compile(optimizer=Adam(lr=0.01,),loss='binary_crossentropy',metrics=['acc'])
    
    return model

# %%
model_dir_path = './models/GRU_0616/best'
callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath=f'{model_dir_path}/BinaryClassification-callback.h5', monitor='val_accuracy', save_best_only=True),
                    tf.keras.callbacks.EarlyStopping(patience=30)]

# %%
def runModels(tried_num,lr,X_train1,X_train2,X_train3,X_train4,Y_train,date, model_dir_path):
    print("***********************************")
    print("model_1 : preprocessing1 with scale")
    print("***********************************")
    model1 = create_model1(learning_rate,X_train1)

    history1=model1.fit(X_train1,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)
    file_name = f'GRU_{date}_model_p1ws_lr={lr}_({tried_num})(3)[best1]'
    plt_performance(history1,path=f'./plot_performance/{date}',filename=file_name)
    model1.save(f"{model_dir_path}/{file_name}.h5")
    keras.backend.clear_session()
    
#     print("***********************************")
#     print("model_2 : preprocessing1 without scale")
#     print("***********************************")
#     model2 = create_model1(learning_rate,X_train2)

#     history2=model2.fit(X_train2,
#                       Y_train,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.2,
#                       callbacks=callback_list,
#                       shuffle=True,
#                       verbose=1)

#     file_name = f'GRU_{date}_modelp1xs_lr={lr}_({tried_num})'
#     plt_performance(history2,path=f'./plot_performance/{date}',filename=file_name)
#     model2.save(f"{model_dir_path}/{file_name}.h5")
#     keras.backend.clear_session()
    
    
#     print("***********************************")
#     print("model_3 : preprocessing2 with scale")
#     print("***********************************")
#     model3 = create_model1(learning_rate,X_train3)

#     history3=model3.fit(X_train3,
#                       Y_train,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.2,
#                       callbacks=callback_list,
#                       shuffle=True,
#                       verbose=1)

    
#     file_name = f'GRU_{date}_modelp2ws_lr={lr}_({tried_num})'
#     plt_performance(history3,path=f'./plot_performance/{date}',filename=file_name)
#     model3.save(f"{model_dir_path}/{file_name}.h5")
#     keras.backend.clear_session()

    
#     print("***********************************")
#     print("model_4 : preprocessing2 without scale")
#     print("***********************************")
#     model4 = create_model1(learning_rate,X_train4)

#     history4=model4.fit(X_train4,
#                       Y_train,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.2,
#                       callbacks=callback_list,
#                       shuffle=True,
#                       verbose=1)

    
#     file_name = f'GRU_{date}_modelp2xs_lr={lr}_({tried_num})'
#     plt_performance(history4,path=f'./plot_performance/{date}',filename=file_name)
#     model4.save(f"{model_dir_path}/{file_name}.h5")
#     keras.backend.clear_session()

# %%
# Set Hyperparameters of the model
epochs = 40
batch_size=128
# learning_rate = 0.0000001
# learning_rates = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
learning_rates = [0.01,0.0001, 0.00001, 0.000001, 0.0000001]
learning_rate = 1e-06
index = 0
tried_num=index
date = '0704'
for learning_rate in learning_rates:
    print(learning_rate)
    tried_num = index
    runModels(tried_num,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train,date,model_dir_path)
    index += 1

# runModels(index
#           ,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train,date,model_dir_path)
# Out:
# 0.01
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/40
# 800/800 [==============================] - 55s 69ms/step - loss: 0.0189 - accuracy: 0.9989 - val_loss: 8.5430e-09 - val_accuracy: 1.0000
# Epoch 2/40
# 800/800 [==============================] - 55s 69ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.7867e-07 - val_accuracy: 1.0000
# Epoch 3/40
# 800/800 [==============================] - 58s 72ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 1.0757e-06 - val_accuracy: 1.0000
# Epoch 4/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.4134e-06 - val_accuracy: 1.0000
# Epoch 5/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 5.1400e-06 - val_accuracy: 1.0000
# Epoch 6/40
# 800/800 [==============================] - 67s 83ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 1.3063e-05 - val_accuracy: 1.0000
# Epoch 7/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 1.5116e-05 - val_accuracy: 1.0000
# Epoch 8/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.7656e-05 - val_accuracy: 1.0000
# Epoch 9/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.2065e-05 - val_accuracy: 1.0000
# Epoch 10/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.9226e-05 - val_accuracy: 1.0000
# Epoch 11/40
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5613e-05 - val_accuracy: 1.0000
# Epoch 12/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3386e-05 - val_accuracy: 1.0000
# Epoch 13/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.9915e-05 - val_accuracy: 1.0000
# Epoch 14/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.4154e-05 - val_accuracy: 1.0000
# Epoch 15/40
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.1075e-05 - val_accuracy: 1.0000
# Epoch 16/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.0071e-05 - val_accuracy: 1.0000
# Epoch 17/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.7075e-05 - val_accuracy: 1.0000
# Epoch 18/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.2592e-05 - val_accuracy: 1.0000
# Epoch 19/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.7719e-05 - val_accuracy: 1.0000
# Epoch 20/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.0656e-05 - val_accuracy: 1.0000
# Epoch 21/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5007e-05 - val_accuracy: 1.0000
# Epoch 22/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3765e-05 - val_accuracy: 1.0000
# Epoch 23/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.3893e-05 - val_accuracy: 1.0000
# Epoch 24/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3147e-05 - val_accuracy: 1.0000
# Epoch 25/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.9583e-05 - val_accuracy: 1.0000
# Epoch 26/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 5.1065e-05 - val_accuracy: 1.0000
# Epoch 27/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.1169e-05 - val_accuracy: 1.0000
# Epoch 28/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.7938e-05 - val_accuracy: 1.0000
# Epoch 29/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.4323e-05 - val_accuracy: 1.0000
# Epoch 30/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.5862e-05 - val_accuracy: 1.0000
# Epoch 31/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.2360e-05 - val_accuracy: 1.0000
# 0.0001
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.6401 - accuracy: 0.9899 - val_loss: 0.2006 - val_accuracy: 1.0000
# Epoch 2/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0910 - accuracy: 0.9998 - val_loss: 0.0290 - val_accuracy: 1.0000
# Epoch 3/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0158 - accuracy: 0.9998 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 4/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0045 - accuracy: 0.9998 - val_loss: 7.8408e-04 - val_accuracy: 1.0000
# Epoch 5/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 1.6206e-04 - val_accuracy: 1.0000
# Epoch 6/40
# 800/800 [==============================] - 64s 79ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 7.5234e-05 - val_accuracy: 1.0000
# Epoch 7/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 1.0406e-04 - val_accuracy: 1.0000
# Epoch 8/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 9.4270e-05 - val_accuracy: 1.0000
# Epoch 9/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 1.0436e-04 - val_accuracy: 1.0000
# Epoch 10/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 3.1543e-05 - val_accuracy: 1.0000
# Epoch 11/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 5.0371e-05 - val_accuracy: 1.0000
# Epoch 12/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 1.1489e-04 - val_accuracy: 1.0000
# Epoch 13/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.0157e-04 - val_accuracy: 1.0000
# Epoch 14/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 6.2353e-05 - val_accuracy: 1.0000
# Epoch 15/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 7.4139e-05 - val_accuracy: 1.0000
# Epoch 16/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 5.2927e-05 - val_accuracy: 1.0000
# Epoch 17/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 1.2164e-04 - val_accuracy: 1.0000
# Epoch 18/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.1932e-05 - val_accuracy: 1.0000
# Epoch 19/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 6.6623e-05 - val_accuracy: 1.0000
# Epoch 20/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 4.5607e-05 - val_accuracy: 1.0000
# Epoch 21/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 2.6523e-05 - val_accuracy: 1.0000
# Epoch 22/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 6.1414e-05 - val_accuracy: 1.0000
# Epoch 23/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 9.3194e-05 - val_accuracy: 1.0000
# Epoch 24/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.8205e-05 - val_accuracy: 1.0000
# Epoch 25/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.1207e-04 - val_accuracy: 1.0000
# Epoch 26/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 1.2965e-04 - val_accuracy: 1.0000
# Epoch 27/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 4.4338e-05 - val_accuracy: 1.0000
# Epoch 28/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 1.5091e-04 - val_accuracy: 1.0000
# Epoch 29/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 5.7003e-05 - val_accuracy: 1.0000
# Epoch 30/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.1010e-05 - val_accuracy: 1.0000
# Epoch 31/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.5723e-05 - val_accuracy: 1.0000
# Epoch 32/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 8.6566e-05 - val_accuracy: 1.0000
# Epoch 33/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 5.6610e-05 - val_accuracy: 1.0000
# Epoch 34/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 4.7991e-05 - val_accuracy: 1.0000
# Epoch 35/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 8.7527e-05 - val_accuracy: 1.0000
# Epoch 36/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 2.1785e-05 - val_accuracy: 1.0000
# Epoch 37/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.7531e-05 - val_accuracy: 1.0000
# Epoch 38/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 2.8197e-05 - val_accuracy: 1.0000
# Epoch 39/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 4.1653e-05 - val_accuracy: 1.0000
# Epoch 40/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 2.6888e-05 - val_accuracy: 1.0000
# 1e-05
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/40
# 800/800 [==============================] - 63s 78ms/step - loss: 1.4215 - accuracy: 0.9168 - val_loss: 1.0984 - val_accuracy: 1.0000
# Epoch 2/40
# 800/800 [==============================] - 64s 80ms/step - loss: 1.0380 - accuracy: 0.9980 - val_loss: 0.9158 - val_accuracy: 1.0000
# Epoch 3/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.8436 - accuracy: 0.9995 - val_loss: 0.7483 - val_accuracy: 1.0000
# Epoch 4/40
# 800/800 [==============================] - 64s 80ms/step - loss: 0.6799 - accuracy: 0.9997 - val_loss: 0.6004 - val_accuracy: 1.0000
# Epoch 5/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5397 - accuracy: 0.9998 - val_loss: 0.4731 - val_accuracy: 1.0000
# Epoch 6/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.4217 - accuracy: 0.9998 - val_loss: 0.3664 - val_accuracy: 1.0000
# Epoch 7/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.3242 - accuracy: 0.9998 - val_loss: 0.2790 - val_accuracy: 1.0000
# Epoch 8/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.2456 - accuracy: 0.9998 - val_loss: 0.2091 - val_accuracy: 1.0000
# Epoch 9/40
# 800/800 [==============================] - 62s 77ms/step - loss: 0.1830 - accuracy: 0.9998 - val_loss: 0.1544 - val_accuracy: 1.0000
# Epoch 10/40
# 800/800 [==============================] - 61s 77ms/step - loss: 0.1349 - accuracy: 0.9998 - val_loss: 0.1125 - val_accuracy: 1.0000
# Epoch 11/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0984 - accuracy: 0.9998 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 12/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0714 - accuracy: 0.9998 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 13/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0514 - accuracy: 0.9998 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 14/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0369 - accuracy: 0.9998 - val_loss: 0.0288 - val_accuracy: 1.0000
# Epoch 15/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0264 - accuracy: 0.9998 - val_loss: 0.0199 - val_accuracy: 1.0000
# Epoch 16/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0190 - accuracy: 0.9998 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 17/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0137 - accuracy: 0.9998 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 18/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0101 - accuracy: 0.9998 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 19/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0078 - accuracy: 0.9998 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 20/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0060 - accuracy: 0.9998 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 21/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0051 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 22/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 23/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0038 - accuracy: 0.9998 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 24/40
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 25/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 8.2544e-04 - val_accuracy: 1.0000
# Epoch 26/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 6.4483e-04 - val_accuracy: 1.0000
# Epoch 27/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 5.2527e-04 - val_accuracy: 1.0000
# Epoch 28/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 4.2507e-04 - val_accuracy: 1.0000
# Epoch 29/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 3.4802e-04 - val_accuracy: 1.0000
# Epoch 30/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 2.6999e-04 - val_accuracy: 1.0000
# Epoch 31/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 2.1365e-04 - val_accuracy: 1.0000
# Epoch 32/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 1.7057e-04 - val_accuracy: 1.0000
# Epoch 33/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.3923e-04 - val_accuracy: 1.0000
# Epoch 34/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.1484e-04 - val_accuracy: 1.0000
# Epoch 35/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 9.5834e-05 - val_accuracy: 1.0000
# Epoch 36/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 8.2139e-05 - val_accuracy: 1.0000
# Epoch 37/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 6.7115e-05 - val_accuracy: 1.0000
# Epoch 38/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 6.2339e-05 - val_accuracy: 1.0000
# Epoch 39/40
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 5.4043e-05 - val_accuracy: 1.0000
# Epoch 40/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 4.4540e-05 - val_accuracy: 1.0000
# 1e-06
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/40
# 800/800 [==============================] - 63s 78ms/step - loss: 2.1361 - accuracy: 0.5396 - val_loss: 1.2792 - val_accuracy: 1.0000
# Epoch 2/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.8270 - accuracy: 0.7195 - val_loss: 1.2478 - val_accuracy: 1.0000
# Epoch 3/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.6274 - accuracy: 0.8415 - val_loss: 1.2300 - val_accuracy: 1.0000
# Epoch 4/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4924 - accuracy: 0.9102 - val_loss: 1.2117 - val_accuracy: 1.0000
# Epoch 5/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3946 - accuracy: 0.9491 - val_loss: 1.1925 - val_accuracy: 1.0000
# Epoch 6/40
# 800/800 [==============================] - 62s 78ms/step - loss: 1.3216 - accuracy: 0.9717 - val_loss: 1.1724 - val_accuracy: 1.0000
# Epoch 7/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.2648 - accuracy: 0.9830 - val_loss: 1.1516 - val_accuracy: 1.0000
# Epoch 8/40
# 800/800 [==============================] - 62s 77ms/step - loss: 1.2176 - accuracy: 0.9897 - val_loss: 1.1299 - val_accuracy: 1.0000
# Epoch 9/40
# 800/800 [==============================] - 63s 78ms/step - loss: 1.1756 - accuracy: 0.9937 - val_loss: 1.1076 - val_accuracy: 1.0000
# Epoch 10/40
# 800/800 [==============================] - 63s 78ms/step - loss: 1.1414 - accuracy: 0.9955 - val_loss: 1.0848 - val_accuracy: 1.0000
# Epoch 11/40
# 800/800 [==============================] - 63s 78ms/step - loss: 1.1083 - accuracy: 0.9970 - val_loss: 1.0616 - val_accuracy: 1.0000
# Epoch 12/40
# 800/800 [==============================] - 63s 78ms/step - loss: 1.0770 - accuracy: 0.9981 - val_loss: 1.0381 - val_accuracy: 1.0000
# Epoch 13/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.0478 - accuracy: 0.9986 - val_loss: 1.0144 - val_accuracy: 1.0000
# Epoch 14/40
# 800/800 [==============================] - 64s 80ms/step - loss: 1.0201 - accuracy: 0.9990 - val_loss: 0.9907 - val_accuracy: 1.0000
# Epoch 15/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9932 - accuracy: 0.9991 - val_loss: 0.9671 - val_accuracy: 1.0000
# Epoch 16/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9672 - accuracy: 0.9994 - val_loss: 0.9436 - val_accuracy: 1.0000
# Epoch 17/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9416 - accuracy: 0.9995 - val_loss: 0.9202 - val_accuracy: 1.0000
# Epoch 18/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9168 - accuracy: 0.9996 - val_loss: 0.8971 - val_accuracy: 1.0000
# Epoch 19/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8926 - accuracy: 0.9997 - val_loss: 0.8742 - val_accuracy: 1.0000
# Epoch 20/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8692 - accuracy: 0.9997 - val_loss: 0.8517 - val_accuracy: 1.0000
# Epoch 21/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.8461 - accuracy: 0.9997 - val_loss: 0.8296 - val_accuracy: 1.0000
# Epoch 22/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8236 - accuracy: 0.9998 - val_loss: 0.8078 - val_accuracy: 1.0000
# Epoch 23/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8017 - accuracy: 0.9998 - val_loss: 0.7864 - val_accuracy: 1.0000
# Epoch 24/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.7799 - accuracy: 0.9998 - val_loss: 0.7653 - val_accuracy: 1.0000
# Epoch 25/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.7588 - accuracy: 0.9998 - val_loss: 0.7447 - val_accuracy: 1.0000
# Epoch 26/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.7384 - accuracy: 0.9998 - val_loss: 0.7246 - val_accuracy: 1.0000
# Epoch 27/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.7181 - accuracy: 0.9998 - val_loss: 0.7048 - val_accuracy: 1.0000
# Epoch 28/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.6982 - accuracy: 0.9998 - val_loss: 0.6854 - val_accuracy: 1.0000
# Epoch 29/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6791 - accuracy: 0.9998 - val_loss: 0.6664 - val_accuracy: 1.0000
# Epoch 30/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6603 - accuracy: 0.9998 - val_loss: 0.6479 - val_accuracy: 1.0000
# Epoch 31/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6418 - accuracy: 0.9998 - val_loss: 0.6298 - val_accuracy: 1.0000
# Epoch 32/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6239 - accuracy: 0.9998 - val_loss: 0.6122 - val_accuracy: 1.0000
# Epoch 33/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6061 - accuracy: 0.9998 - val_loss: 0.5949 - val_accuracy: 1.0000
# Epoch 34/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5891 - accuracy: 0.9998 - val_loss: 0.5780 - val_accuracy: 1.0000
# Epoch 35/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5723 - accuracy: 0.9998 - val_loss: 0.5614 - val_accuracy: 1.0000
# Epoch 36/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.5559 - accuracy: 0.9998 - val_loss: 0.5453 - val_accuracy: 1.0000
# Epoch 37/40
# 800/800 [==============================] - 63s 79ms/step - loss: 0.5401 - accuracy: 0.9998 - val_loss: 0.5296 - val_accuracy: 1.0000
# Epoch 38/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5244 - accuracy: 0.9998 - val_loss: 0.5142 - val_accuracy: 1.0000
# Epoch 39/40
# 800/800 [==============================] - 62s 78ms/step - loss: 0.5094 - accuracy: 0.9998 - val_loss: 0.4992 - val_accuracy: 1.0000
# Epoch 40/40
# 800/800 [==============================] - 63s 78ms/step - loss: 0.4943 - accuracy: 0.9998 - val_loss: 0.4845 - val_accuracy: 1.0000
# 1e-07
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/40
# 800/800 [==============================] - 63s 78ms/step - loss: 2.1338 - accuracy: 0.5318 - val_loss: 2.7153 - val_accuracy: 0.1633
# Epoch 2/40
# 800/800 [==============================] - 63s 79ms/step - loss: 2.0898 - accuracy: 0.5572 - val_loss: 2.8303 - val_accuracy: 0.1709
# Epoch 3/40
# 800/800 [==============================] - 63s 79ms/step - loss: 2.0490 - accuracy: 0.5834 - val_loss: 2.6881 - val_accuracy: 0.1844
# Epoch 4/40
# 800/800 [==============================] - 62s 78ms/step - loss: 2.0161 - accuracy: 0.6016 - val_loss: 2.5824 - val_accuracy: 0.1994
# Epoch 5/40
# 800/800 [==============================] - 62s 78ms/step - loss: 1.9815 - accuracy: 0.6236 - val_loss: 2.6740 - val_accuracy: 0.1885
# Epoch 6/40
# 800/800 [==============================] - 62s 78ms/step - loss: 1.9465 - accuracy: 0.6465 - val_loss: 2.4285 - val_accuracy: 0.2286
# Epoch 7/40
# 800/800 [==============================] - 63s 78ms/step - loss: 1.9145 - accuracy: 0.6685 - val_loss: 2.4195 - val_accuracy: 0.2302
# Epoch 8/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.8841 - accuracy: 0.6882 - val_loss: 2.3217 - val_accuracy: 0.2270
# Epoch 9/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1
40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4041 - accuracy: 0.9555 - val_loss: 1.2658 - val_accuracy: 1.0000
# Epoch 36/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3945 - accuracy: 0.9588 - val_loss: 1.2479 - val_accuracy: 1.0000
# Epoch 37/40
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3844 - accuracy: 0.9611 - val_loss: 1.2440 - val_accuracy: 1.0000
# Epoch 38/40
# 800/800 [==============================] - 62s 78ms/step - loss: 1.3748 - accuracy: 0.9644 - val_loss: 1.2307 - val_accuracy: 1.0000
# Epoch 39/40
# 800/800 [==============================] - 62s 78ms/step - loss: 1.3666 - accuracy: 0.9673 - val_loss: 1.2265 - val_accuracy: 1.0000
# Epoch 40/40
# 800/800 [==============================] - 64s 79ms/step - loss: 1.3576 - accuracy: 0.9692 - val_loss: 1.2216 - val_accuracy: 1.0000

# %%
def setTraindata(segmented, valence_data, arousal_data, type='valence'):
    if type == 'valence':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
        Y_train = y_train_data.reshape((y_train_data.shape[0],))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    elif type == 'arousal':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
        Y_train = y_train_data.reshape((y_train_data.shape[0],))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    else:
        print("type error")
        
    return X_train, Y_train

X_train1, Y_train = setTraindata(segmented1, valence_data, arousal_data)
X_train2, Y_train = setTraindata(segmented2, valence_data, arousal_data)
X_train3, Y_train = setTraindata(segmented3, valence_data, arousal_data)
X_train4, Y_train = setTraindata(segmented4, valence_data, arousal_data)
# Out:
# X_train shape : (128000, 1280, 1), Y_train shape : (40,)
# X_train shape : (128000, 1280, 1), Y_train shape : (40,)
# X_train shape : (125400, 1280, 1), Y_train shape : (40,)
# X_train shape : (125400, 1280, 1), Y_train shape : (40,)

# %%
def create_model1(learning_rate, X_train):

    model = Sequential()
    model.add(GRU(units=128,
                  dropout=0.3,
                  # recurrent_dropout=0.25,
                  return_sequences=False,
                  recurrent_regularizer='l2',
                  input_shape=[X_train.shape[1],X_train.shape[2]]))
                  # input_shape=[X_train.shape[0],X_train.shape[1]]))
    model.add(BatchNormalization())

    # Dense net
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))

    # callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='BinaryClassification_Dense3-callback.h5', monitor='val_accuracy', save_best_only=True),
    #                 tf.keras.callbacks.EarlyStopping(patience=10)]

    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=learning_rate), metrics=['accuracy'])
    model.summary()


#     from tensorflow.keras.layers import Activation
#     model = Sequential()
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2]),return_sequences=True))
#     model.add(Dropout(0.4))
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2])))
#     model.add(Dropout(0.3))
#     model.add(Dense(100))
#     model.add(Dense(1))
#     model.add(Activation('sigmoid'))
#     model.summary()

#     from tensorflow.keras.optimizers import Adam
#     model.compile(optimizer=Adam(lr=0.01,),loss='binary_crossentropy',metrics=['acc'])
    
    return model

# %%
def runModels(tried_num,lr,X_train1,X_train2,X_train3,X_train4,Y_train,date, model_dir_path):
    print("***********************************")
    print("model_1 : preprocessing1 with scale")
    print("***********************************")
    model1 = create_model1(learning_rate,X_train1)

    history1=model1.fit(X_train1,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)
    file_name = f'GRU_{date}_model_p1ws_lr={lr}_({tried_num})(4)[best2]'
    plt_performance(history1,path=f'./plot_performance/{date}',filename=file_name)
    model1.save(f"{model_dir_path}/{file_name}.h5")
    keras.backend.clear_session()
    
#     print("***********************************")
#     print("model_2 : preprocessing1 without scale")
#     print("***********************************")
#     model2 = create_model1(learning_rate,X_train2)

#     history2=model2.fit(X_train2,
#                       Y_train,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.2,
#                       callbacks=callback_list,
#                       shuffle=True,
#                       verbose=1)

#     file_name = f'GRU_{date}_modelp1xs_lr={lr}_({tried_num})(2)'
#     plt_performance(history2,path=f'./plot_performance/{date}',filename=file_name)
#     model2.save(f"{model_dir_path}/{file_name}.h5")
#     keras.backend.clear_session()
    
    
#     print("***********************************")
#     print("model_3 : preprocessing2 with scale")
#     print("***********************************")
#     model3 = create_model1(learning_rate,X_train3)

#     history3=model3.fit(X_train3,
#                       Y_train,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.2,
#                       callbacks=callback_list,
#                       shuffle=True,
#                       verbose=1)

    
#     file_name = f'GRU_{date}_modelp2ws_lr={lr}_({tried_num})(2)'
#     plt_performance(history3,path=f'./plot_performance/{date}',filename=file_name)
#     model3.save(f"{model_dir_path}/{file_name}.h5")
#     keras.backend.clear_session()

    
#     print("***********************************")
#     print("model_4 : preprocessing2 without scale")
#     print("***********************************")
#     model4 = create_model1(learning_rate,X_train4)

#     history4=model4.fit(X_train4,
#                       Y_train,
#                       epochs=epochs,
#                       batch_size=batch_size,
#                       validation_split=0.2,
#                       callbacks=callback_list,
#                       shuffle=True,
#                       verbose=1)

    
#     file_name = f'GRU_{date}_modelp2xs_lr={lr}_({tried_num})(2)'
#     plt_performance(history4,path=f'./plot_performance/{date}',filename=file_name)
#     model4.save(f"{model_dir_path}/{file_name}.h5")
#     keras.backend.clear_session()
    
# Set Hyperparameters of the model
epochs = 50
batch_size=128
# learning_rate = 0.0000001
# learning_rates = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
learning_rates = [0.01,0.0001, 0.00001, 0.000001, 0.0000001]
# learning_rate = 1e-06
index = 0
date = '0704'
for learning_rate in learning_rates:
    print(learning_rate)
    tried_num = index
    runModels(tried_num,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train,date,model_dir_path)
    index += 1
# runModels(index
#           ,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train,date,model_dir_path)
# Out:
# 0.01
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 800/800 [==============================] - 61s 76ms/step - loss: 0.0192 - accuracy: 0.9989 - val_loss: 3.3232e-08 - val_accuracy: 1.0000
# Epoch 2/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.0695e-07 - val_accuracy: 1.0000
# Epoch 3/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 1.0297e-06 - val_accuracy: 1.0000
# Epoch 4/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0158 - accuracy: 0.9998 - val_loss: 0.7292 - val_accuracy: 1.0000
# Epoch 5/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0127 - accuracy: 0.9998 - val_loss: 3.5596e-06 - val_accuracy: 1.0000
# Epoch 6/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 9.0038e-06 - val_accuracy: 1.0000
# Epoch 7/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 1.1863e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 1.5446e-05 - val_accuracy: 1.0000
# Epoch 9/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.5852e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5962e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.2137e-05 - val_accuracy: 1.0000
# Epoch 12/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.7870e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3233e-05 - val_accuracy: 1.0000
# Epoch 14/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.8783e-05 - val_accuracy: 1.0000
# Epoch 15/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5294e-05 - val_accuracy: 1.0000
# Epoch 16/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.8067e-05 - val_accuracy: 1.0000
# Epoch 17/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.9381e-05 - val_accuracy: 1.0000
# Epoch 18/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5249e-05 - val_accuracy: 1.0000
# Epoch 19/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5052e-05 - val_accuracy: 1.0000
# Epoch 20/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.1753e-05 - val_accuracy: 1.0000
# Epoch 21/50
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.7292e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.1651e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.4082e-05 - val_accuracy: 1.0000
# Epoch 24/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3043e-05 - val_accuracy: 1.0000
# Epoch 25/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.7205e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3581e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.1680e-05 - val_accuracy: 1.0000
# Epoch 28/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.5656e-05 - val_accuracy: 1.0000
# Epoch 29/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 2.9108e-05 - val_accuracy: 1.0000
# Epoch 30/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 3.3709e-05 - val_accuracy: 1.0000
# Epoch 31/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 4.8356e-05 - val_accuracy: 1.0000
# 0.0001
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6661 - accuracy: 0.9859 - val_loss: 0.2219 - val_accuracy: 1.0000
# Epoch 2/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.1060 - accuracy: 0.9998 - val_loss: 0.0387 - val_accuracy: 1.0000
# Epoch 3/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0218 - accuracy: 0.9998 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 4/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0067 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 5/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 4.0925e-04 - val_accuracy: 1.0000
# Epoch 6/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 1.7332e-04 - val_accuracy: 1.0000
# Epoch 7/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 8.1234e-05 - val_accuracy: 1.0000
# Epoch 8/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 1.2109e-04 - val_accuracy: 1.0000
# Epoch 9/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 4.5529e-05 - val_accuracy: 1.0000
# Epoch 10/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 6.8252e-05 - val_accuracy: 1.0000
# Epoch 11/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 1.0254e-04 - val_accuracy: 1.0000
# Epoch 12/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 9.1832e-05 - val_accuracy: 1.0000
# Epoch 13/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 5.3108e-05 - val_accuracy: 1.0000
# Epoch 14/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 8.8882e-05 - val_accuracy: 1.0000
# Epoch 15/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 6.2992e-05 - val_accuracy: 1.0000
# Epoch 16/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 5.8226e-05 - val_accuracy: 1.0000
# Epoch 17/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 4.3670e-05 - val_accuracy: 1.0000
# Epoch 18/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 5.8435e-05 - val_accuracy: 1.0000
# Epoch 19/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 6.9095e-05 - val_accuracy: 1.0000
# Epoch 20/50
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 2.8952e-05 - val_accuracy: 1.0000
# Epoch 21/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 6.1408e-05 - val_accuracy: 1.0000
# Epoch 22/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 2.7012e-05 - val_accuracy: 1.0000
# Epoch 23/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 4.3063e-05 - val_accuracy: 1.0000
# Epoch 24/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.1071e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 8.5109e-05 - val_accuracy: 1.0000
# Epoch 26/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 5.3401e-05 - val_accuracy: 1.0000
# Epoch 27/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.9617e-05 - val_accuracy: 1.0000
# Epoch 28/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 2.0519e-05 - val_accuracy: 1.0000
# Epoch 29/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 3.0967e-05 - val_accuracy: 1.0000
# Epoch 30/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 8.2485e-05 - val_accuracy: 1.0000
# Epoch 31/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 5.5234e-05 - val_accuracy: 1.0000
# Epoch 32/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.9392e-05 - val_accuracy: 1.0000
# Epoch 33/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 5.3038e-05 - val_accuracy: 1.0000
# Epoch 34/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 8.7493e-05 - val_accuracy: 1.0000
# Epoch 35/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 6.4154e-05 - val_accuracy: 1.0000
# Epoch 36/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.4871e-05 - val_accuracy: 1.0000
# Epoch 37/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 6.3527e-05 - val_accuracy: 1.0000
# Epoch 38/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.6165e-05 - val_accuracy: 1.0000
# Epoch 39/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.1365e-05 - val_accuracy: 1.0000
# Epoch 40/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 9.7013e-05 - val_accuracy: 1.0000
# Epoch 41/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.9260e-05 - val_accuracy: 1.0000
# Epoch 42/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 4.5295e-05 - val_accuracy: 1.0000
# Epoch 43/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.9926e-05 - val_accuracy: 1.0000
# Epoch 44/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.8573e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 7.0290e-05 - val_accuracy: 1.0000
# Epoch 46/50
# 800/800 [==============================] - 62s 77ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.9995e-05 - val_accuracy: 1.0000
# Epoch 47/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.2185e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.4942e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.9172e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 3.6738e-05 - val_accuracy: 1.0000
# 1e-05
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.3290 - accuracy: 0.9608 - val_loss: 1.0785 - val_accuracy: 1.0000
# Epoch 2/50
# 800/800 [==============================] - 64s 79ms/step - loss: 0.9996 - accuracy: 0.9992 - val_loss: 0.8820 - val_accuracy: 1.0000
# Epoch 3/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8014 - accuracy: 0.9997 - val_loss: 0.7073 - val_accuracy: 1.0000
# Epoch 4/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6355 - accuracy: 0.9998 - val_loss: 0.5575 - val_accuracy: 1.0000
# Epoch 5/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.4965 - accuracy: 0.9998 - val_loss: 0.4323 - val_accuracy: 1.0000
# Epoch 6/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.3824 - accuracy: 0.9998 - val_loss: 0.3300 - val_accuracy: 1.0000
# Epoch 7/50
# 800/800 [==============================] - 61s 77ms/step - loss: 0.2899 - accuracy: 0.9998 - val_loss: 0.2481 - val_accuracy: 1.0000
# Epoch 8/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.2173 - accuracy: 0.9998 - val_loss: 0.1844 - val_accuracy: 1.0000
# Epoch 9/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.1608 - accuracy: 0.9998 - val_loss: 0.1351 - val_accuracy: 1.0000
# Epoch 10/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.1178 - accuracy: 0.9998 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 11/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0852 - accuracy: 0.9998 - val_loss: 0.0700 - val_accuracy: 1.0000
# Epoch 12/50
# 800/800 [==============================] - 64s 80ms/step - loss: 0.0615 - accuracy: 0.9998 - val_loss: 0.0495 - val_accuracy: 1.0000
# Epoch 13/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0439 - accuracy: 0.9998 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 14/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0310 - accuracy: 0.9998 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 15/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0220 - accuracy: 0.9998 - val_loss: 0.0165 - val_accuracy: 1.0000
# Epoch 16/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0156 - accuracy: 0.9998 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 17/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0115 - accuracy: 0.9998 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 18/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0087 - accuracy: 0.9998 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 19/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0067 - accuracy: 0.9998 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 20/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0053 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 21/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0042 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 22/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 23/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 9.3982e-04 - val_accuracy: 1.0000
# Epoch 24/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 6.8776e-04 - val_accuracy: 1.0000
# Epoch 25/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 5.1534e-04 - val_accuracy: 1.0000
# Epoch 26/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 3.9702e-04 - val_accuracy: 1.0000
# Epoch 27/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 3.1793e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 2.5542e-04 - val_accuracy: 1.0000
# Epoch 29/50
# 800/800 [==============================] - 64s 79ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 2.1223e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.6779e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 1.3888e-04 - val_accuracy: 1.0000
# Epoch 32/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 1.1453e-04 - val_accuracy: 1.0000
# Epoch 33/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 9.1217e-05 - val_accuracy: 1.0000
# Epoch 34/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 7.4743e-05 - val_accuracy: 1.0000
# Epoch 35/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 5.9235e-05 - val_accuracy: 1.0000
# Epoch 36/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 4.7678e-05 - val_accuracy: 1.0000
# Epoch 37/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.9162e-05 - val_accuracy: 1.0000
# Epoch 38/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 3.3104e-05 - val_accuracy: 1.0000
# Epoch 39/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 2.9433e-05 - val_accuracy: 1.0000
# Epoch 40/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 2.6879e-05 - val_accuracy: 1.0000
# Epoch 41/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.5075e-05 - val_accuracy: 1.0000
# Epoch 42/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.0410e-05 - val_accuracy: 1.0000
# Epoch 43/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.3729e-05 - val_accuracy: 1.0000
# Epoch 44/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 2.0395e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 1.6542e-05 - val_accuracy: 1.0000
# Epoch 46/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 1.5351e-05 - val_accuracy: 1.0000
# Epoch 47/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.6039e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 1.4635e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 1.4953e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 1.5269e-05 - val_accuracy: 1.0000
# 1e-06
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 800/800 [==============================] - 62s 78ms/step - loss: 2.2326 - accuracy: 0.4534 - val_loss: 2.3862 - val_accuracy: 0.6203
# Epoch 2/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.9166 - accuracy: 0.6459 - val_loss: 1.6213 - val_accuracy: 0.8163
# Epoch 3/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.6997 - accuracy: 0.7907 - val_loss: 1.3504 - val_accuracy: 0.9273
# Epoch 4/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.5481 - accuracy: 0.8813 - val_loss: 1.2357 - val_accuracy: 1.0000
# Epoch 5/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.4359 - accuracy: 0.9345 - val_loss: 1.1997 - val_accuracy: 1.0000
# Epoch 6/50
# 800/800 [==============================] - 62s 77ms/step - loss: 1.3567 - accuracy: 0.9624 - val_loss: 1.1758 - val_accuracy: 1.0000
# Epoch 7/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.2920 - accuracy: 0.9789 - val_loss: 1.1544 - val_accuracy: 1.0000
# Epoch 8/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.2402 - accuracy: 0.9870 - val_loss: 1.1327 - val_accuracy: 1.0000
# Epoch 9/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.1952 - accuracy: 0.9923 - val_loss: 1.1104 - val_accuracy: 1.0000
# Epoch 10/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.1552 - accuracy: 0.9952 - val_loss: 1.0878 - val_accuracy: 1.0000
# Epoch 11/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.1204 - accuracy: 0.9967 - val_loss: 1.0646 - val_accuracy: 1.0000
# Epoch 12/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.0873 - accuracy: 0.9980 - val_loss: 1.0413 - val_accuracy: 1.0000
# Epoch 13/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.0570 - accuracy: 0.9988 - val_loss: 1.0176 - val_accuracy: 1.0000
# Epoch 14/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.0273 - accuracy: 0.9990 - val_loss: 0.9940 - val_accuracy: 1.0000
# Epoch 15/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.9994 - accuracy: 0.9993 - val_loss: 0.9703 - val_accuracy: 1.0000
# Epoch 16/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9729 - accuracy: 0.9995 - val_loss: 0.9467 - val_accuracy: 1.0000
# Epoch 17/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9469 - accuracy: 0.9996 - val_loss: 0.9232 - val_accuracy: 1.0000
# Epoch 18/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.9214 - accuracy: 0.9997 - val_loss: 0.9000 - val_accuracy: 1.0000
# Epoch 19/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8967 - accuracy: 0.9997 - val_loss: 0.8770 - val_accuracy: 1.0000
# Epoch 20/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.8727 - accuracy: 0.9997 - val_loss: 0.8544 - val_accuracy: 1.0000
# Epoch 21/50
# 800/800 [==============================] - 64s 79ms/step - loss: 0.8493 - accuracy: 0.9997 - val_loss: 0.8320 - val_accuracy: 1.0000
# Epoch 22/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.8263 - accuracy: 0.9998 - val_loss: 0.8101 - val_accuracy: 1.0000
# Epoch 23/50
# 800/800 [==============================] - 64s 80ms/step - loss: 0.8041 - accuracy: 0.9998 - val_loss: 0.7885 - val_accuracy: 1.0000
# Epoch 24/50
# 800/800 [==============================] - 64s 79ms/step - loss: 0.7822 - accuracy: 0.9998 - val_loss: 0.7674 - val_accuracy: 1.0000
# Epoch 25/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.7609 - accuracy: 0.9998 - val_loss: 0.7466 - val_accuracy: 1.0000
# Epoch 26/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.7400 - accuracy: 0.9998 - val_loss: 0.7263 - val_accuracy: 1.0000
# Epoch 27/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.7197 - accuracy: 0.9998 - val_loss: 0.7064 - val_accuracy: 1.0000
# Epoch 28/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.6999 - accuracy: 0.9998 - val_loss: 0.6869 - val_accuracy: 1.0000
# Epoch 29/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6804 - accuracy: 0.9998 - val_loss: 0.6679 - val_accuracy: 1.0000
# Epoch 30/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6616 - accuracy: 0.9998 - val_loss: 0.6493 - val_accuracy: 1.0000
# Epoch 31/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.6431 - accuracy: 0.9998 - val_loss: 0.6311 - val_accuracy: 1.0000
# Epoch 32/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.6249 - accuracy: 0.9998 - val_loss: 0.6134 - val_accuracy: 1.0000
# Epoch 33/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.6076 - accuracy: 0.9998 - val_loss: 0.5961 - val_accuracy: 1.0000
# Epoch 34/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5902 - accuracy: 0.9998 - val_loss: 0.5791 - val_accuracy: 1.0000
# Epoch 35/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5734 - accuracy: 0.9998 - val_loss: 0.5626 - val_accuracy: 1.0000
# Epoch 36/50
# 800/800 [==============================] - 62s 78ms/step - loss: 0.5572 - accuracy: 0.9998 - val_loss: 0.5465 - val_accuracy: 1.0000
# Epoch 37/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5411 - accuracy: 0.9998 - val_loss: 0.5307 - val_accuracy: 1.0000
# Epoch 38/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0.5254 - accuracy: 0.9998 - val_loss: 0.5154 - val_accuracy: 1.0000
# Epoch 39/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.5100 - accuracy: 0.9998 - val_loss: 0.5003 - val_accuracy: 1.0000
# Epoch 40/50
# 800/800 [==============================] - 63s 79ms/step - loss: 0.4953 - accuracy: 0.9998 - val_loss: 0.4856 - val_accuracy: 1.0000
# Epoch 41/50
# 800/800 [==============================] - 63s 78ms/step - loss: 0
50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.9496 - accuracy: 0.6577 - val_loss: 2.4904 - val_accuracy: 0.8574
# Epoch 14/50
# 800/800 [==============================] - 64s 80ms/step - loss: 1.9136 - accuracy: 0.6757 - val_loss: 2.3727 - val_accuracy: 0.8689
# Epoch 15/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.8860 - accuracy: 0.6932 - val_loss: 2.2799 - val_accuracy: 0.8751
# Epoch 16/50
# 800/800 [==============================] - 62s 78ms/step - loss: 1.8612 - accuracy: 0.7086 - val_loss: 2.0851 - val_accuracy: 0.8871
# Epoch 17/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.8355 - accuracy: 0.7238 - val_loss: 2.0574 - val_accuracy: 0.8955
# Epoch 18/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.8124 - accuracy: 0.7357 - val_loss: 2.0570 - val_accuracy: 0.8978
# Epoch 19/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.7867 - accuracy: 0.7502 - val_loss: 1.8564 - val_accuracy: 0.8993
# Epoch 20/50
# 800/800 [==============================] - 64s 80ms/step - loss: 1.7644 - accuracy: 0.7657 - val_loss: 1.8118 - val_accuracy: 0.8996
# Epoch 21/50
# 800/800 [==============================] - 61s 77ms/step - loss: 1.7437 - accuracy: 0.7781 - val_loss: 1.7203 - val_accuracy: 0.8999
# Epoch 22/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.7239 - accuracy: 0.7880 - val_loss: 1.6094 - val_accuracy: 0.9022
# Epoch 23/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.6995 - accuracy: 0.8038 - val_loss: 1.5818 - val_accuracy: 0.9025
# Epoch 24/50
# 800/800 [==============================] - 64s 80ms/step - loss: 1.6842 - accuracy: 0.8127 - val_loss: 1.5391 - val_accuracy: 0.9026
# Epoch 25/50
# 800/800 [==============================] - 62s 78ms/step - loss: 1.6617 - accuracy: 0.8264 - val_loss: 1.3984 - val_accuracy: 0.9252
# Epoch 26/50
# 800/800 [==============================] - 62s 78ms/step - loss: 1.6434 - accuracy: 0.8356 - val_loss: 1.3807 - val_accuracy: 0.9310
# Epoch 27/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.6274 - accuracy: 0.8451 - val_loss: 1.3058 - val_accuracy: 0.9680
# Epoch 28/50
# 800/800 [==============================] - 62s 78ms/step - loss: 1.6106 - accuracy: 0.8545 - val_loss: 1.2855 - val_accuracy: 0.9739
# Epoch 29/50
# 800/800 [==============================] - 62s 77ms/step - loss: 1.5928 - accuracy: 0.8637 - val_loss: 1.2800 - val_accuracy: 0.9743
# Epoch 30/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.5773 - accuracy: 0.8717 - val_loss: 1.2596 - val_accuracy: 0.9894
# Epoch 31/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.5615 - accuracy: 0.8810 - val_loss: 1.2380 - val_accuracy: 0.9986
# Epoch 32/50
# 800/800 [==============================] - 62s 78ms/step - loss: 1.5460 - accuracy: 0.8895 - val_loss: 1.2368 - val_accuracy: 0.9981
# Epoch 33/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.5339 - accuracy: 0.8955 - val_loss: 1.2276 - val_accuracy: 0.9997
# Epoch 34/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.5144 - accuracy: 0.9040 - val_loss: 1.2317 - val_accuracy: 0.9994
# Epoch 35/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.5046 - accuracy: 0.9091 - val_loss: 1.2279 - val_accuracy: 0.9995
# Epoch 36/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4924 - accuracy: 0.9150 - val_loss: 1.2209 - val_accuracy: 0.9999
# Epoch 37/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4784 - accuracy: 0.9215 - val_loss: 1.2193 - val_accuracy: 0.9999
# Epoch 38/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4689 - accuracy: 0.9249 - val_loss: 1.2166 - val_accuracy: 1.0000
# Epoch 39/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.4560 - accuracy: 0.9313 - val_loss: 1.2141 - val_accuracy: 1.0000
# Epoch 40/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4452 - accuracy: 0.9357 - val_loss: 1.2122 - val_accuracy: 1.0000
# Epoch 41/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4336 - accuracy: 0.9403 - val_loss: 1.2100 - val_accuracy: 1.0000
# Epoch 42/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4236 - accuracy: 0.9437 - val_loss: 1.2080 - val_accuracy: 1.0000
# Epoch 43/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.4132 - accuracy: 0.9468 - val_loss: 1.2059 - val_accuracy: 1.0000
# Epoch 44/50
# 800/800 [==============================] - 63s 78ms/step - loss: 1.4023 - accuracy: 0.9520 - val_loss: 1.2038 - val_accuracy: 1.0000
# Epoch 45/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3951 - accuracy: 0.9535 - val_loss: 1.2018 - val_accuracy: 1.0000
# Epoch 46/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3834 - accuracy: 0.9573 - val_loss: 1.1997 - val_accuracy: 1.0000
# Epoch 47/50
# 800/800 [==============================] - 64s 80ms/step - loss: 1.3752 - accuracy: 0.9598 - val_loss: 1.1976 - val_accuracy: 1.0000
# Epoch 48/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3672 - accuracy: 0.9627 - val_loss: 1.1954 - val_accuracy: 1.0000
# Epoch 49/50
# 800/800 [==============================] - 64s 80ms/step - loss: 1.3590 - accuracy: 0.9647 - val_loss: 1.1933 - val_accuracy: 1.0000
# Epoch 50/50
# 800/800 [==============================] - 63s 79ms/step - loss: 1.3519 - accuracy: 0.9661 - val_loss: 1.1912 - val_accuracy: 1.0000

# %%
timestep = 1280
stride = 128
# normalized1 = [normalized1[0]]
# normalized2 = [normalized2[0]]
# normalized3 = [normalized3[0]]
# normalized4 = [normalized4[0]]
segmented1, valence_data, arousal_data = segmentate(normalized1, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 with scale
segmented2, valence_data, arousal_data = segmentate(normalized2, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 without scale
segmented3, valence_data, arousal_data = segmentate(normalized3, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 with scale
segmented4, valence_data, arousal_data = segmentate(normalized4, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 without scale
# Out:
# 2000
# 2000
# 1960
# 1960

# %%
X_train1, Y_train = setTraindata(segmented1, valence_data, arousal_data)
X_train2, Y_train = setTraindata(segmented2, valence_data, arousal_data)
X_train3, Y_train = setTraindata(segmented3, valence_data, arousal_data)
X_train4, Y_train = setTraindata(segmented4, valence_data, arousal_data)
# Out:
# X_train shape : (2000, 1280, 1), Y_train shape : (40,)
# X_train shape : (2000, 1280, 1), Y_train shape : (40,)
# X_train shape : (1960, 1280, 1), Y_train shape : (40,)
# X_train shape : (1960, 1280, 1), Y_train shape : (40,)

# %%
epochs = 50
batch_size=128
# learning_rate = 0.0000001
# learning_rates = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
learning_rates = [0.01,0.0001, 0.00001, 0.000001, 0.0000001]
# learning_rate = 1e-06
index = 0
date = '0705'
for learning_rate in learning_rates:
    print(learning_rate)
    tried_num = index
    runModels(tried_num,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train,date,model_dir_path)
    index += 1
# Out:
# 0.01
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 13/13 [==============================] - 1s 73ms/step - loss: 1.0176 - accuracy: 0.8925 - val_loss: 0.3146 - val_accuracy: 1.0000
# Epoch 2/50
# 13/13 [==============================] - 1s 78ms/step - loss: 0.3658 - accuracy: 0.9875 - val_loss: 0.1467 - val_accuracy: 1.0000
# Epoch 3/50
# 13/13 [==============================] - 1s 75ms/step - loss: 0.2024 - accuracy: 0.9875 - val_loss: 0.0714 - val_accuracy: 1.0000
# Epoch 4/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.1671 - accuracy: 0.9881 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 5/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.1543 - accuracy: 0.9869 - val_loss: 0.0346 - val_accuracy: 1.0000
# Epoch 6/50
# 13/13 [==============================] - 1s 73ms/step - loss: 0.1395 - accuracy: 0.9881 - val_loss: 0.0190 - val_accuracy: 1.0000
# Epoch 7/50
# 13/13 [==============================] - 1s 73ms/step - loss: 0.1093 - accuracy: 0.9881 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 8/50
# 13/13 [==============================] - 1s 73ms/step - loss: 0.1172 - accuracy: 0.9862 - val_loss: 0.0258 - val_accuracy: 1.0000
# Epoch 9/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.1067 - accuracy: 0.9875 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 10/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.1109 - accuracy: 0.9881 - val_loss: 0.0205 - val_accuracy: 1.0000
# Epoch 11/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.1123 - accuracy: 0.9881 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 12/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.0917 - accuracy: 0.9862 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 13/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.0903 - accuracy: 0.9881 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 14/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0822 - accuracy: 0.9881 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 15/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.0960 - accuracy: 0.9881 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 16/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.0854 - accuracy: 0.9881 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 17/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.0824 - accuracy: 0.9881 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 18/50
# 13/13 [==============================] - 1s 77ms/step - loss: 0.0793 - accuracy: 0.9881 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 19/50
# 13/13 [==============================] - 1s 72ms/step - loss: 0.0750 - accuracy: 0.9881 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 20/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0861 - accuracy: 0.9881 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 21/50
# 13/13 [==============================] - 1s 74ms/step - loss: 0.0866 - accuracy: 0.9862 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 22/50
# 13/13 [==============================] - 1s 75ms/step - loss: 0.0876 - accuracy: 0.9881 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 23/50
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0921 - accuracy: 0.9875 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 24/50
# 13/13 [==============================] - 1s 78ms/step - loss: 0.0981 - accuracy: 0.9875 - val_loss: 0.0180 - val_accuracy: 1.0000
# Epoch
# 13/13 [==============================] - 1s 73ms/step - loss: 2.6067 - accuracy: 0.2856 - val_loss: 2.7038 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 13/13 [==============================] - 1s 76ms/step - loss: 2.5812 - accuracy: 0.2975 - val_loss: 2.8303 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 13/13 [==============================] - 1s 77ms/step - loss: 2.6020 - accuracy: 0.2825 - val_loss: 2.9683 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 13/13 [==============================] - 1s 79ms/step - loss: 2.5729 - accuracy: 0.2912 - val_loss: 3.1242 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 13/13 [==============================] - 1s 78ms/step - loss: 2.5931 - accuracy: 0.2937 - val_loss: 3.3000 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 13/13 [==============================] - 1s 76ms/step - loss: 2.5614 - accuracy: 0.3088 - val_loss: 3.4941 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 13/13 [==============================] - 1s 81ms/step - loss: 2.5801 - accuracy: 0.3194 - val_loss: 3.6951 - val_accuracy: 0.0000e+00
# 1e-07
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/50
# 13/13 [==============================] - 1s 78ms/step - loss: 2.4653 - accuracy: 0.3150 - val_loss: 1.9520 - val_accuracy: 0.9725
# Epoch 2/50
# 13/13 [==============================] - 1s 76ms/step - loss: 2.4963 - accuracy: 0.3187 - val_loss: 1.9898 - val_accuracy: 0.2325
# Epoch 3/50
# 13/13 [==============================] - 1s 77ms/step - loss: 2.4934 - accuracy: 0.3131 - val_loss: 2.0256 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 13/13 [==============================] - 1s 76ms/step - loss: 2.5097 - accuracy: 0.3237 - val_loss: 2.0422 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 13/13 [==============================] - 1s 74ms/step - loss: 2.4933 - accuracy: 0.3269 - val_loss: 2.0548 - val_accuracy: 0.0625
# Epoch 6/50
# 13/13 [==============================] - 1s 76ms/step - loss: 2.4672 - accuracy: 0.3225 - val_loss: 2.0696 - val_accuracy: 0.1525
# Epoch 7/50
# 13/13 [==============================] - 1s 73ms/step - loss: 2.4908 - accuracy: 0.3194 - val_loss: 2.0918 - val_accuracy: 0.1600
# Epoch 8/50
# 13/13 [==============================] - 1s 74ms/step - loss: 2.4961 - accuracy: 0.3231 - val_loss: 2.1158 - val_accuracy: 0.1700
# Epoch 9/50
# 13/13 [==============================] - 1s 75ms/step - loss: 2.4400 - accuracy: 0.3363 - val_loss: 2.1322 - val_accuracy: 0.2000
# Epoch 10/50
# 13/13 [==============================] - 1s 78ms/step - loss: 2.4626 - accuracy: 0.3250 - val_loss: 2.1438 - val_accuracy: 0.1975
# Epoch 11/50
# 13/13 [==============================] - 1s 75ms/step - loss: 2.4807 - accuracy: 0.3200 - val_loss: 2.1518 - val_accuracy: 0.2050
# Epoch 12/50

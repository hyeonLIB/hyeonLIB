# %%
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from scipy.signal import find_peaks
from scipy import signal
from scipy.integrate import trapz
from scipy.interpolate import interp1d
import seaborn as sns
import heartpy as hp
import os
import pickle
import warnings
warnings.simplefilter('ignore', np.RankWarning)

# %%
def plt_performance(history, path='./', filename=''):
    epoch = list(range(0,len(history.history['loss'])))
    
    fig, (his_accuracy, his_loss) = plt.subplots(nrows=2,ncols=1,figsize=(10,8),sharex=True)
    his_loss.plot(epoch, history.history['loss'], label='Training loss')
    his_loss.plot(epoch, history.history['val_loss'], label='Validation loss')
    his_loss.set_xlabel("Epochs", fontsize=14)
    his_loss.set_ylabel("Loss", fontsize=14)
    his_loss.set_title("Loss", fontsize=14)
    his_loss.legend(loc='best')
    
    his_accuracy.plot(epoch, history.history['accuracy'], label='Training accuracy')
    his_accuracy.plot(epoch, history.history['val_accuracy'], label='Validation accuracy')
    his_accuracy.set_xlabel("Epochs", fontsize=14)
    his_accuracy.set_ylabel("Accuracy", fontsize=14)
    his_accuracy.set_title("Accuracy", fontsize=14)
    his_accuracy.legend(loc='best')
    
    fig.tight_layout()
    if filename == '':
        plt.savefig(f'{path}/GRU/performance.png', bbox_inches='tight')
    else:
        plt.savefig(f'{path}/GRU/{filename}.png', bbox_inches='tight')
    plt.show()
    
"""
Pre-processing method
"""

def preprocessing1(PPG_data):
    """
    Fast Emotion Recognition reference
    """

    index = 0
    x = list(range(0,len(PPG_data[0])))
    
    for PPG in PPG_data:
        poly = np.polyfit(x, PPG, deg=50)
        polied = np.polyval(poly, x)
        detrended = PPG - polied
        PPG_data[index] = detrended
        index += 1
        
    return PPG_data


def preprocessing2(ppg_data, view = False, participant = ''):
    """
    Analysis PPG signal reference
    """
    
    # moving average function
    m_avg = lambda t, x, w : (np.asarray([t[i] for i in range(w, len(x) - w)]),
                          np.convolve(x, np.ones((2*w + 1, )) / (2*w + 1),
                                      mode = 'valid'))

    fs = len(ppg_data)/(60)  # sample rate

    # moving average
    w_size = int(fs*.5)  # width of moving window
    times = list(range(0,len(ppg_data)))
    mt, ms = m_avg(times, ppg_data, w_size)

    sign = (ppg_data[w_size:-w_size]-ms)

    analytical_signal = np.abs(signal.hilbert(sign))

    fs = len(sign) / (max(mt) - min(mt))
    w_size = int(fs)
    mt_new, mov_avg = m_avg(mt, analytical_signal, w_size)

    signal_pure = sign[w_size : -w_size] / mov_avg
    
    if view:
        plt.ioff()
        
        fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, ncols = 1, figsize = (10, 8), sharex=True)
        ax1.plot(times, ppg_data, "b-", label="Original")
        ax1.legend(loc='best')
        ax1.set_title("participants"+str(participant)+" Raw", fontsize=14)#, fontweight="bold")

        ax2.plot(mt, sign, 'r-', label="Pure signal")
        ax2.plot(mt_new, mov_avg, 'b-', label='Modulation', alpha=.5)
        ax2.legend(loc='best')
        ax2.set_title("Raw -> filtered", fontsize=14)#, fontweight="bold")

        ax3.plot(mt_new, signal_pure, "g-", label="Demodulated")
        ax3.set_xlim(0, mt[-1])
        ax3.set_title("Raw -> filtered -> demodulated", fontsize=14)#, fontweight="bold")

        ax3.set_xlabel("Time (sec)", fontsize=14) # common axis label
        ax3.legend(loc='best')

        fig.tight_layout()
        plt.savefig(f'./plot_img/{participant}.png', bbox_inches='tight')
        
    return signal_pure

    
def get_peaks(ppg_processed):
    diff_sig_2 = np.diff(ppg_processed) ## do
    peaks_2, _ = find_peaks(diff_sig_2, distance=100*(30/60), prominence=0.01)
    result = []
    peaks = []
    
    for i in range(len(peaks_2)):
        if diff_sig_2[peaks_2][i] > 40:
            result.append(peaks_2[i])
            peaks.append(diff_sig_2[peaks_2][i])
            
    return result, peaks, diff_sig_2

# %%
dir_list_ = os.listdir("./data")
dir_list_.sort()
count = 0
dir_list = []
for i in range(22):
    dir_list.append(dir_list_[i])
    
#### pop unavailable data
dir_list.pop(5)
dir_list.pop(2)

print(dir_list)
df_PPG = pd.DataFrame(columns=['participant','video_number','ppg','valence','arousal'])
Valence_data = []
Arousal_data = []
PPG_data = []
dir_list = dir_list[:1]

file_num = 0
for file in dir_list:
    dat_file = f'./data/{file}'
    with open(dat_file, 'rb') as f:
        Channel_data = pickle.load(f,encoding='latin1')
    data = Channel_data["data"]
    labels = Channel_data["labels"]
    for video_num in range(40):
        dataP = data[video_num,38]
        dataP = dataP[384:]
        
        label = labels[video_num]
        if label[0] < 5:
            Valence = 0
        if label[0] >= 5:
            Valence = 1
        if label[1] < 5:
            Arousal = 0
        if label[1] >= 5:
            Arousal = 1
        instance = [(file_num, video_num, dataP, Valence, Arousal)]
        new_instance = pd.DataFrame(instance, columns=['participant','video_number','ppg','valence','arousal'])
        df_PPG = pd.concat([df_PPG, new_instance], ignore_index = True)
        PPG_data.append(dataP)
        Valence_data.append(Valence)
        Arousal_data.append(Arousal)
    file_num += 1
    
PPG_shape = np.array(PPG_data)
PPG_shape.shape
# Out:
# ['s01.dat', 's02.dat', 's04.dat', 's05.dat', 's07.dat', 's08.dat', 's09.dat', 's10.dat', 's11.dat', 's12.dat', 's13.dat', 's14.dat', 's15.dat', 's16.dat', 's17.dat', 's18.dat', 's19.dat', 's20.dat', 's21.dat', 's22.dat']
# (40, 7680)

# %%
# Concatenate PPG data of each person to use min-max normalization method 
def normalizing(preprocessed, scale=False):
    i = 1
    new_PPG = []
    tmp_PPG = np.empty(0)
    for PPG in preprocessed:
        if i % 40 != 0:
            tmp_PPG = np.concatenate([tmp_PPG, PPG])
        else:
            tmp_PPG = np.concatenate([tmp_PPG, PPG])
            new_PPG.append(tmp_PPG)
            tmp_PPG = np.empty(0)
        i += 1


    # Normalize personal PPG data and Split into per video
    new_PPG = np.array(new_PPG)
    new_PPG.shape[0]
    new_PPG = new_PPG.reshape(new_PPG.shape[0],new_PPG.shape[1],1)

    normalized = []
    
    if scale==True:
        for PPG in new_PPG:
            # Normalized personal PPG
            scaler = MinMaxScaler()
            norm = scaler.fit_transform(PPG) * 1000

            # Split into per video
            for i in range(40):
                norm_video = norm[i*7680 : i*7680+7680]
                normalized.append(norm_video)
    else:
        for PPG in new_PPG:
            # Normalized personal PPG
            scaler = MinMaxScaler()
            norm = scaler.fit_transform(PPG)

            # Split into per video
            for i in range(40):
                norm_video = norm[i*7680 : i*7680+7680]
                normalized.append(norm_video)
                

    normalized = np.array(normalized)
    print(normalized.shape)
    
    return normalized


def segmentate(normalized, Arousal_data, Valence_data, timestep=1280, stride=128):
    segmented = []
    valence_data = []
    arousal_data = []

    idx = 0
    for PPG in normalized:
        for index in range(0, len(PPG) - timestep, stride):
            segmented.append(PPG[index : index + timestep,:])
            #############
            valence_data.append(Valence_data[idx])
            arousal_data.append(Arousal_data[idx])
        idx += 1
    print(len(segmented))
    
    return segmented, valence_data, arousal_data

# %%
print("Valence label 0 : ",Valence_data.count(0))
print("Valence label 1 : ",Valence_data.count(1))

print("Arousal label 0 : ",Arousal_data.count(0))
print("Arousal label 1 : ",Arousal_data.count(1))
# Out:
# Valence label 0 :  21
# Valence label 1 :  19
# Arousal label 0 :  16
# Arousal label 1 :  24

# %% [markdown]
# ## Preprocessing method 1, 2

# %%
PPG_data = df_PPG['ppg']

preprocessed1 = preprocessing1(PPG_data)
# Out:
# /home/sselab/anaconda3/envs/EmotionRecognition/lib/python3.8/site-packages/numpy/lib/polynomial.py:627: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/sselab/anaconda3/envs/EmotionRecognition/lib/python3.8/site-packages/numpy/core/_methods.py:47: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)

# %%
preprocessed2 = []

for PPG in PPG_data:
    preprocessed_d = preprocessing2(PPG,view=False)
    preprocessed2.append(preprocessed_d)

preprocessed2 = np.array(preprocessed2)

# %% [markdown]
# ## Normalization * 1000 or not

# %%
normalized1 = normalizing(preprocessed1, scale=True)
normalized2 = normalizing(preprocessed1, scale=False)
normalized3 = normalizing(preprocessed2, scale=True)
normalized4 = normalizing(preprocessed2, scale=False)
# Out:
# (40, 7680, 1)
# (40, 7680, 1)
# (40,)
# (40,)
# <ipython-input-4-0e285f3dd935>:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)
# <ipython-input-4-0e285f3dd935>:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   normalized = np.array(normalized)

# %% [markdown]
# ## segmentation

# %%
timestep = 1280
stride = 2
# normalized1 = [normalized1[0]]
# normalized2 = [normalized2[0]]
# normalized3 = [normalized3[0]]
# normalized4 = [normalized4[0]]
segmented1, valence_data, arousal_data = segmentate(normalized1, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 with scale
segmented2, valence_data, arousal_data = segmentate(normalized2, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 1 without scale
segmented3, valence_data, arousal_data = segmentate(normalized3, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 with scale
segmented4, valence_data, arousal_data = segmentate(normalized4, Arousal_data, Valence_data,timestep=timestep,stride=stride) # preprocessing 2 without scale
# Out:
# 128000
# 128000
# 125400
# 125400

# %%
times = list(range(0,len(segmented1[0])))
plt.plot(times,segmented1[0])
plt.plot(times,segmented3[0])

# %%
import tensorflow as tf
tf.config.experimental_run_functions_eagerly(True)
from tensorflow import keras
from tensorflow.keras import layers, callbacks
# from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LSTM, GRU

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 2 GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10000)]) # limit in megabytes
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
def setTraindata(segmented, valence_data, arousal_data, type='valence'):
    if type == 'valence':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
        Y_train = y_train_data.reshape((y_train_data.shape[0],1))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    elif type == 'arousal':
        train_x = segmented
        train_valence = valence_data
        train_arousal = arousal_data

        x_train_data = np.array(train_x).astype(np.float32)
        y_train_data = np.array(train_valence).astype(np.float32)

        X_train = x_train_data.reshape((x_train_data.shape[0], x_train_data.shape[1],1))
        Y_train = y_train_data.reshape((y_train_data.shape[0],1))

        print(f"X_train shape : {X_train.shape}, Y_train shape : {Y_train.shape}")
    else:
        print("type error")
        
    return X_train, Y_train

# %%
X_train1, Y_train = setTraindata(segmented1, valence_data, arousal_data)
X_train2, Y_train = setTraindata(segmented2, valence_data, arousal_data)
X_train3, Y_train = setTraindata(segmented3, valence_data, arousal_data)
X_train4, Y_train = setTraindata(segmented4, valence_data, arousal_data)
# Out:
# X_train shape : (128000, 1280, 1), Y_train shape : (125400, 1)
# X_train shape : (128000, 1280, 1), Y_train shape : (125400, 1)
# X_train shape : (125400, 1280, 1), Y_train shape : (125400, 1)
# X_train shape : (125400, 1280, 1), Y_train shape : (125400, 1)

# %%
def create_model1(learning_rate, X_train):

    model = Sequential()
    model.add(GRU(units=128,
                  dropout=0.3,
                  # recurrent_dropout=0.25,
                  return_sequences=False,
                  recurrent_regularizer='l2',
                  input_shape=[X_train.shape[1],X_train.shape[2]]))
    model.add(BatchNormalization())

    # Dense net
    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))

    # callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath='BinaryClassification_Dense3-callback.h5', monitor='val_accuracy', save_best_only=True),
    #                 tf.keras.callbacks.EarlyStopping(patience=10)]

    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=learning_rate), metrics=['accuracy'])
    model.summary()


#     from tensorflow.keras.layers import Activation
#     model = Sequential()
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2]),return_sequences=True))
#     model.add(Dropout(0.4))
#     model.add(LSTM(64,input_shape=(None,X_train.shape[2])))
#     model.add(Dropout(0.3))
#     model.add(Dense(100))
#     model.add(Dense(1))
#     model.add(Activation('sigmoid'))
#     model.summary()

#     from tensorflow.keras.optimizers import Adam
#     model.compile(optimizer=Adam(lr=0.01,),loss='binary_crossentropy',metrics=['acc'])
    
    return model

# %%
model_dir_path = './models/GRU_0616'
callback_list = [tf.keras.callbacks.ModelCheckpoint(filepath=f'{model_dir_path}/BinaryClassification-callback.h5', monitor='val_accuracy', save_best_only=True),
                    tf.keras.callbacks.EarlyStopping(patience=3)]

# %%
def runModels(tried_num,lr,X_train1,X_train2,X_train3,X_train4,Y_train,date, model_dir_path):
    print("***********************************")
    print("model_1 : preprocessing1 with scale")
    print("***********************************")
    model1 = create_model1(learning_rate,X_train1)

    history1=model1.fit(X_train1,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)
    file_name = f'GRU_{date}_model_p1ws_lr={lr}_({tried_num})'
    plt_performance(history1,path=f'./plot_performance/{date}',filename=file_name)
    model1.save(f"{model_dir_path}/{file_name}.h5")
    keras.backend.clear_session()
    
    print("***********************************")
    print("model_2 : preprocessing1 without scale")
    print("***********************************")
    model2 = create_model1(learning_rate,X_train2)

    history2=model2.fit(X_train2,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)

    file_name = f'GRU_{date}_modelp1xs_lr={lr}_({tried_num})'
    plt_performance(history2,path=f'./plot_performance/{date}',filename=file_name)
    model2.save(f"{model_dir_path}/{file_name}.h5")
    keras.backend.clear_session()
    
    
    print("***********************************")
    print("model_3 : preprocessing2 with scale")
    print("***********************************")
    model3 = create_model1(learning_rate,X_train3)

    history3=model3.fit(X_train3,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)

    
    file_name = f'GRU_{date}_modelp2ws_lr={lr}_({tried_num})'
    plt_performance(history3,path=f'./plot_performance/{date}',filename=file_name)
    model3.save(f"{model_dir_path}/{file_name}.h5")
    keras.backend.clear_session()

    
    print("***********************************")
    print("model_4 : preprocessing2 without scale")
    print("***********************************")
    model4 = create_model1(learning_rate,X_train4)

    history4=model4.fit(X_train4,
                      Y_train,
                      epochs=epochs,
                      batch_size=batch_size,
                      validation_split=0.2,
                      callbacks=callback_list,
                      shuffle=True,
                      verbose=1)

    
    file_name = f'GRU_{date}_modelp2xs_lr={lr}_({tried_num})'
    plt_performance(history4,path=f'./plot_performance/{date}',filename=file_name)
    model4.save(f"{model_dir_path}/{file_name}.h5")
    keras.backend.clear_session()

# %%
# Set Hyperparameters of the model
epochs = 15
batch_size=128
# learning_rate = 0.0000001
# learning_rates = [0.01, 0.001, 0.0001, 0.00001, 0.000001]
learning_rates = [0.0001, 0.00001, 0.000001, 0.0000001]
index = 0
date = '0612'
for learning_rate in learning_rates:
    print(learning_rate)
    tried_num = index
    runModels(tried_num,learning_rate,X_train1,X_train2,X_train3,X_train4,Y_train,date,model_dir_path)
    index += 1
# Out:
# 0.0001
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 54s 67ms/step - loss: 1.5266 - accuracy: 0.5227 - val_loss: 0.6479 - val_accuracy: 0.9765
# Epoch 2/15
# 800/800 [==============================] - 54s 67ms/step - loss: 0.9930 - accuracy: 0.5252 - val_loss: 0.3188 - val_accuracy: 0.9766
# Epoch 3/15
# 800/800 [==============================] - 56s 70ms/step - loss: 0.8298 - accuracy: 0.5306 - val_loss: 0.3622 - val_accuracy: 0.8922
# Epoch 4/15
# 800/800 [==============================] - 58s 72ms/step - loss: 0.7668 - accuracy: 0.5336 - val_loss: 0.2141 - val_accuracy: 0.9766
# Epoch 5/15
# 800/800 [==============================] - 59s 73ms/step - loss: 0.7350 - accuracy: 0.5374 - val_loss: 0.3000 - val_accuracy: 0.9766
# Epoch 6/15
# 800/800 [==============================] - 64s 80ms/step - loss: 0.7174 - accuracy: 0.5413 - val_loss: 0.4555 - val_accuracy: 0.9766
# Epoch 7/15
# 800/800 [==============================] - 60s 76ms/step - loss: 0.7072 - accuracy: 0.5436 - val_loss: 0.4365 - val_accuracy: 0.9766
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 60s 75ms/step - loss: 1.4148 - accuracy: 0.5214 - val_loss: 1.1125 - val_accuracy: 0.0234
# Epoch 2/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.9086 - accuracy: 0.5256 - val_loss: 0.9552 - val_accuracy: 0.0234
# Epoch 3/15
# 800/800 [==============================] - 60s 75ms/step - loss: 0.7807 - accuracy: 0.5285 - val_loss: 0.8911 - val_accuracy: 0.0234
# Epoch 4/15
# 800/800 [==============================] - 60s 76ms/step - loss: 0.7283 - accuracy: 0.5342 - val_loss: 0.8776 - val_accuracy: 0.0234
# Epoch 5/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.7067 - accuracy: 0.5383 - val_loss: 0.8200 - val_accuracy: 0.0234
# Epoch 6/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.6982 - accuracy: 0.5405 - val_loss: 0.8160 - val_accuracy: 0.0234
# Epoch 7/15
# 800/800 [==============================] - 61s 77ms/step - loss: 0.6940 - accuracy: 0.5450 - val_loss: 0.8059 - val_accuracy: 0.0234
# Epoch 8/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.6919 - accuracy: 0.5479 - val_loss: 0.8188 - val_accuracy: 0.0234
# Epoch 9/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.6902 - accuracy: 0.5510 - val_loss: 0.8157 - val_accuracy: 0.0234
# Epoch 10/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.6894 - accuracy: 0.5528 - val_loss: 0.8165 - val_accuracy: 0.0234
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 60s 76ms/step - loss: 1.5085 - accuracy: 0.5251 - val_loss: 0.7802 - val_accuracy: 0.9761
# Epoch 2/15
# 784/784 [==============================] - 60s 77ms/step - loss: 0.9550 - accuracy: 0.5314 - val_loss: 6.4112 - val_accuracy: 0.0239
# Epoch 3/15
# 784/784 [==============================] - 60s 77ms/step - loss: 0.7952 - accuracy: 0.5376 - val_loss: 1.6377 - val_accuracy: 0.0239
# Epoch 4/15
# 784/784 [==============================] - 59s 75ms/step - loss: 0.7408 - accuracy: 0.5391 - val_loss: 4.2314 - val_accuracy: 0.0239
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 59s 76ms/step - loss: 1.4303 - accuracy: 0.5215 - val_loss: 1.0450 - val_accuracy: 0.3307
# Epoch 2/15
# 784/784 [==============================] - 59s 76ms/step - loss: 0.9121 - accuracy: 0.5305 - val_loss: 0.8329 - val_accuracy: 0.2263
# Epoch 3/15
# 784/784 [==============================] - 60s 76ms/step - loss: 0.7809 - accuracy: 0.5354 - val_loss: 0.8178 - val_accuracy: 0.0702
# Epoch 4/15
# 784/784 [==============================] - 60s 76ms/step - loss: 0.7298 - accuracy: 0.5386 - val_loss: 0.7699 - val_accuracy: 0.0239
# Epoch 5/15
# 784/784 [==============================] - 59s 76ms/step - loss: 0.7072 - accuracy: 0.5422 - val_loss: 0.7648 - val_accuracy: 0.0239
# Epoch 6/15
# 784/784 [==============================] - 59s 75ms/step - loss: 0.6971 - accuracy: 0.5495 - val_loss: 0.7734 - val_accuracy: 0.0239
# Epoch 7/15
# 784/784 [==============================] - 60s 77ms/step - loss: 0.6919 - accuracy: 0.5551 - val_loss: 0.7708 - val_accuracy: 0.0239
# Epoch 8/15
# 784/784 [==============================] - 65s 83ms/step - loss: 0.6893 - accuracy: 0.5591 - val_loss: 0.8177 - val_accuracy: 0.0239
# 1e-05
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.0880 - accuracy: 0.4892 - val_loss: 2.5081 - val_accuracy: 0.4226
# Epoch 2/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.8729 - accuracy: 0.5159 - val_loss: 2.4296 - val_accuracy: 0.4294
# Epoch 3/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.7292 - accuracy: 0.5158 - val_loss: 2.8144 - val_accuracy: 0.2838
# Epoch 4/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.6018 - accuracy: 0.5167 - val_loss: 2.8996 - val_accuracy: 0.2680
# Epoch 5/15
# 800/800 [==============================] - 65s 82ms/step - loss: 1.4947 - accuracy: 0.5161 - val_loss: 2.0570 - val_accuracy: 0.4213
# Epoch 6/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.3981 - accuracy: 0.5171 - val_loss: 1.7916 - val_accuracy: 0.4149
# Epoch 7/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.3162 - accuracy: 0.5170 - val_loss: 1.2875 - val_accuracy: 0.6381
# Epoch 8/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.2414 - accuracy: 0.5204 - val_loss: 1.0439 - val_accuracy: 0.7493
# Epoch 9/15
# 800/800 [==============================] - 62s 78ms/step - loss: 1.1761 - accuracy: 0.5219 - val_loss: 0.9166 - val_accuracy: 0.7640
# Epoch 10/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.1196 - accuracy: 0.5237 - val_loss: 1.1644 - val_accuracy: 0.6660
# Epoch 11/15
# 800/800 [==============================] - 61s 77ms/step - loss: 1.0707 - accuracy: 0.5246 - val_loss: 1.0249 - val_accuracy: 0.7082
# Epoch 12/15
# 800/800 [==============================] - 61s 77ms/step - loss: 1.0282 - accuracy: 0.5228 - val_loss: 1.0277 - val_accuracy: 0.6314
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.0099 - accuracy: 0.5103 - val_loss: 1.9850 - val_accuracy: 0.0691
# Epoch 2/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.7949 - accuracy: 0.5154 - val_loss: 1.8517 - val_accuracy: 0.0263
# Epoch 3/15
# 800/800 [==============================] - 61s 77ms/step - loss: 1.6270 - accuracy: 0.5177 - val_loss: 1.7036 - val_accuracy: 0.0307
# Epoch 4/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.4900 - accuracy: 0.5188 - val_loss: 1.5395 - val_accuracy: 0.0368
# Epoch 5/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.3771 - accuracy: 0.5187 - val_loss: 1.4487 - val_accuracy: 0.0240
# Epoch 6/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.2808 - accuracy: 0.5217 - val_loss: 1.3459 - val_accuracy: 0.0340
# Epoch 7/15
# 800/800 [==============================] - 62s 78ms/step - loss: 1.2006 - accuracy: 0.5222 - val_loss: 1.2851 - val_accuracy: 0.0247
# Epoch 8/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.1369 - accuracy: 0.5220 - val_loss: 1.2426 - val_accuracy: 0.0245
# Epoch 9/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.0801 - accuracy: 0.5231 - val_loss: 1.1648 - val_accuracy: 0.0277
# Epoch 10/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.0312 - accuracy: 0.5254 - val_loss: 1.1295 - val_accuracy: 0.0253
# Epoch 11/15
# 800/800 [==============================] - 61s 76ms/step - loss: 0.9940 - accuracy: 0.5215 - val_loss: 1.1152 - val_accuracy: 0.0234
# Epoch 12/15
# 800/800 [==============================] - 61s 77ms/step - loss: 0.9607 - accuracy: 0.5265 - val_loss: 1.0903 - val_accuracy: 0.0234
# Epoch 13/15
# 800/800 [==============================] - 62s 77ms/step - loss: 0.9328 - accuracy: 0.5248 - val_loss: 1.0593 - val_accuracy: 0.0234
# Epoch 14/15
# 800/800 [==============================] - 61s 77ms/step - loss: 0.9070 - accuracy: 0.5299 - val_loss: 1.0532 - val_accuracy: 0.0255
# Epoch 15/15
# 800/800 [==============================] - 62s 78ms/step - loss: 0.8884 - accuracy: 0.5257 - val_loss: 1.0216 - val_accuracy: 0.0234
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 60s 77ms/step - loss: 2.0479 - accuracy: 0.5106 - val_loss: 1.4067 - val_accuracy: 0.9761
# Epoch 2/15
# 784/784 [==============================] - 61s 77ms/step - loss: 1.8690 - accuracy: 0.5168 - val_loss: 1.2642 - val_accuracy: 0.9761
# Epoch 3/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.7227 - accuracy: 0.5214 - val_loss: 1.1291 - val_accuracy: 0.9761
# Epoch 4/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.5954 - accuracy: 0.5221 - val_loss: 0.9999 - val_accuracy: 0.9761
# Epoch 5/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.4883 - accuracy: 0.5202 - val_loss: 0.8865 - val_accuracy: 0.9761
# Epoch 6/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.3889 - accuracy: 0.5256 - val_loss: 0.7558 - val_accuracy: 0.9761
# Epoch 7/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.3042 - accuracy: 0.5259 - val_loss: 0.6813 - val_accuracy: 0.9761
# Epoch 8/15
# 784/784 [==============================] - 59s 76ms/step - loss: 1.2311 - accuracy: 0.5280 - val_loss: 0.5821 - val_accuracy: 0.9761
# Epoch 9/15
# 784/784 [==============================] - 61s 77ms/step - loss: 1.1644 - accuracy: 0.5287 - val_loss: 0.5170 - val_accuracy: 0.9761
# Epoch 10/15
# 784/784 [==============================] - 60s 76ms/step - loss: 1.1078 - accuracy: 0.5273 - val_loss: 0.4643 - val_accuracy: 0.9761
# Epoch 11/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.0598 - accuracy: 0.5278 - val_loss: 0.4314 - val_accuracy: 0.9761
# Epoch 12/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.0152 - accuracy: 0.5317 - val_loss: 0.4364 - val_accuracy: 0.9761
# Epoch 13/15
# 784/784 [==============================] - 60s 76ms/step - loss: 0.9792 - accuracy: 0.5301 - val_loss: 0.7890 - val_accuracy: 0.8530
# Epoch 14/15
# 784/784 [==============================] - 60s 76ms/step - loss: 0.9459 - accuracy: 0.5294 - val_loss: 0.6215 - val_accuracy: 0.9705
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 60s 77ms/step - loss: 2.0212 - accuracy: 0.5287 - val_loss: 1.6802 - val_accuracy: 0.9460
# Epoch 2/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.8015 - accuracy: 0.5242 - val_loss: 1.4917 - val_accuracy: 0.9464
# Epoch 3/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.6332 - accuracy: 0.5275 - val_loss: 1.3626 - val_accuracy: 0.9292
# Epoch 4/15
# 784/784 [==============================] - 60s 76ms/step - loss: 1.4950 - accuracy: 0.5261 - val_loss: 1.2422 - val_accuracy: 0.9751
# Epoch 5/15
# 784/784 [==============================] - 59s 76ms/step - loss: 1.3799 - accuracy: 0.5256 - val_loss: 1.1781 - val_accuracy: 0.8867
# Epoch 6/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.2834 - accuracy: 0.5288 - val_loss: 1.0908 - val_accuracy: 0.9524
# Epoch 7/15
# 784/784 [==============================] - 59s 76ms/step - loss: 1.2017 - accuracy: 0.5285 - val_loss: 1.0256 - val_accuracy: 0.9192
# Epoch 8/15
# 784/784 [==============================] - 59s 76ms/step - loss: 1.1350 - accuracy: 0.5283 - val_loss: 0.9728 - val_accuracy: 0.9515
# Epoch 9/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.0811 - accuracy: 0.5266 - val_loss: 0.9432 - val_accuracy: 0.8819
# Epoch 10/15
# 784/784 [==============================] - 61s 78ms/step - loss: 1.0308 - accuracy: 0.5287 - val_loss: 0.9159 - val_accuracy: 0.8902
# Epoch 11/15
# 784/784 [==============================] - 67s 86ms/step - loss: 0.9901 - accuracy: 0.5314 - val_loss: 0.9012 - val_accuracy: 0.7606
# Epoch 12/15
# 784/784 [==============================] - 63s 80ms/step - loss: 0.9556 - accuracy: 0.5322 - val_loss: 0.8689 - val_accuracy: 0.8052
# Epoch 13/15
# 784/784 [==============================] - 61s 78ms/step - loss: 0.9268 - accuracy: 0.5343 - val_loss: 0.8457 - val_accuracy: 0.8088
# Epoch 14/15
# 784/784 [==============================] - 60s 76ms/step - loss: 0.9024 - accuracy: 0.5315 - val_loss: 0.8418 - val_accuracy: 0.5860
# Epoch 15/15
# 784/784 [==============================] - 59s 76ms/step - loss: 0.8813 - accuracy: 0.5327 - val_loss: 0.8237 - val_accuracy: 0.6523
# 1e-06
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.1451 - accuracy: 0.5165 - val_loss: 5.1450 - val_accuracy: 0.2047
# Epoch 2/15
# 800/800 [==============================] - 61s 77ms/step - loss: 2.1107 - accuracy: 0.5181 - val_loss: 5.0719 - val_accuracy: 0.2047
# Epoch 3/15
# 800/800 [==============================] - 66s 83ms/step - loss: 2.0909 - accuracy: 0.5162 - val_loss: 4.7037 - val_accuracy: 0.2559
# Epoch 4/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.0688 - accuracy: 0.5177 - val_loss: 4.3067 - val_accuracy: 0.3066
# Epoch 5/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.0466 - accuracy: 0.5188 - val_loss: 3.9231 - val_accuracy: 0.3384
# Epoch 6/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.0293 - accuracy: 0.5176 - val_loss: 3.9085 - val_accuracy: 0.3493
# Epoch 7/15
# 800/800 [==============================] - 62s 78ms/step - loss: 2.0133 - accuracy: 0.5159 - val_loss: 3.4594 - val_accuracy: 0.4002
# Epoch 8/15
# 800/800 [==============================] - 61s 77ms/step - loss: 1.9928 - accuracy: 0.5170 - val_loss: 3.2253 - val_accuracy: 0.4325
# Epoch 9/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.9741 - accuracy: 0.5164 - val_loss: 3.3668 - val_accuracy: 0.3932
# Epoch 10/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.9531 - accuracy: 0.5179 - val_loss: 3.1054 - val_accuracy: 0.4191
# Epoch 11/15
# 800/800 [==============================] - 61s 77ms/step - loss: 1.9395 - accuracy: 0.5203 - val_loss: 3.0505 - val_accuracy: 0.4117
# Epoch 12/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.9215 - accuracy: 0.5168 - val_loss: 3.3142 - val_accuracy: 0.3483
# Epoch 13/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.9050 - accuracy: 0.5178 - val_loss: 3.2805 - val_accuracy: 0.3047
# Epoch 14/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.8923 - accuracy: 0.5127 - val_loss: 3.0873 - val_accuracy: 0.3506
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.1554 - accuracy: 0.5280 - val_loss: 1.9551 - val_accuracy: 0.4718
# Epoch 2/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.1005 - accuracy: 0.5252 - val_loss: 1.9211 - val_accuracy: 0.6100
# Epoch 3/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.0712 - accuracy: 0.5208 - val_loss: 1.8916 - val_accuracy: 0.5715
# Epoch 4/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.0431 - accuracy: 0.5159 - val_loss: 1.8628 - val_accuracy: 0.5736
# Epoch 5/15
# 800/800 [==============================] - 63s 78ms/step - loss: 2.0188 - accuracy: 0.5177 - val_loss: 1.8515 - val_accuracy: 0.4912
# Epoch 6/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.9938 - accuracy: 0.5165 - val_loss: 1.8341 - val_accuracy: 0.4741
# Epoch 7/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.9676 - accuracy: 0.5167 - val_loss: 1.8191 - val_accuracy: 0.4422
# Epoch 8/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.9400 - accuracy: 0.5202 - val_loss: 1.8033 - val_accuracy: 0.4252
# Epoch 9/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.9209 - accuracy: 0.5176 - val_loss: 1.7834 - val_accuracy: 0.4227
# Epoch 10/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.8973 - accuracy: 0.5179 - val_loss: 1.7680 - val_accuracy: 0.4016
# Epoch 11/15
# 800/800 [==============================] - 61s 76ms/step - loss: 1.8756 - accuracy: 0.5179 - val_loss: 1.7482 - val_accuracy: 0.4081
# Epoch 12/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.8534 - accuracy: 0.5174 - val_loss: 1.7426 - val_accuracy: 0.3821
# Epoch 13/15
# 800/800 [==============================] - 62s 78ms/step - loss: 1.8310 - accuracy: 0.5199 - val_loss: 1.7240 - val_accuracy: 0.3840
# Epoch 14/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.8099 - accuracy: 0.5203 - val_loss: 1.7032 - val_accuracy: 0.3874
# Epoch 15/15
# 800/800 [==============================] - 62s 77ms/step - loss: 1.7908 - accuracy: 0.5193 - val_loss: 1.6872 - val_accuracy: 0.3889
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 61s 77ms/step - loss: 2.2096 - accuracy: 0.4805 - val_loss: 11.5359 - val_accuracy: 0.0239
# Epoch 2/15
# 784/784 [==============================] - 61s 77ms/step - loss: 2.1481 - accuracy: 0.4860 - val_loss: 11.7315 - val_accuracy: 0.0239
# Epoch 3/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.1117 - accuracy: 0.4950 - val_loss: 9.7761 - val_accuracy: 0.0239
# Epoch 4/15
# 784/784 [==============================] - 61s 77ms/step - loss: 2.0864 - accuracy: 0.5010 - val_loss: 9.7463 - val_accuracy: 0.0239
# Epoch 5/15
# 784/784 [==============================] - 61s 77ms/step - loss: 2.0593 - accuracy: 0.5056 - val_loss: 7.9882 - val_accuracy: 0.0239
# Epoch 6/15
# 784/784 [==============================] - 62s 79ms/step - loss: 2.0382 - accuracy: 0.5104 - val_loss: 7.4720 - val_accuracy: 0.0239
# Epoch 7/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.0201 - accuracy: 0.5098 - val_loss: 7.3767 - val_accuracy: 0.0239
# Epoch 8/15
# 784/784 [==============================] - 60s 77ms/step - loss: 2.0022 - accuracy: 0.5144 - val_loss: 6.6267 - val_accuracy: 0.0239
# Epoch 9/15
# 784/784 [==============================] - 61s 78ms/step - loss: 1.9820 - accuracy: 0.5142 - val_loss: 6.0427 - val_accuracy: 0.0239
# Epoch 10/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.9651 - accuracy: 0.5167 - val_loss: 4.5980 - val_accuracy: 0.0276
# Epoch 11/15
# 784/784 [==============================] - 61s 78ms/step - loss: 1.9503 - accuracy: 0.5142 - val_loss: 4.2341 - val_accuracy: 0.0345
# Epoch 12/15
# 784/784 [==============================] - 61s 78ms/step - loss: 1.9290 - accuracy: 0.5171 - val_loss: 3.5606 - val_accuracy: 0.0681
# Epoch 13/15
# 784/784 [==============================] - 61s 78ms/step - loss: 1.9092 - accuracy: 0.5181 - val_loss: 3.1351 - val_accuracy: 0.0972
# Epoch 14/15
# 784/784 [==============================] - 61s 78ms/step - loss: 1.8964 - accuracy: 0.5177 - val_loss: 2.9060 - val_accuracy: 0.1096
# Epoch 15/15
# 784/784 [==============================] - 60s 77ms/step - loss: 1.8850 - accuracy: 0.5138 - val_loss: 2.3545 - val_accuracy: 0.1687
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 60s 77ms/step - loss: 2.1299 - accuracy: 0.5065 - val_loss: 2.0980 - val_accuracy: 0.1297
# Epoch 2/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.0925 - accuracy: 0.5098 - val_loss: 2.1220 - val_accuracy: 0.0239
# Epoch 3/15
# 784/784 [==============================] - 61s 77ms/step - loss: 2.0694 - accuracy: 0.5128 - val_loss: 2.1398 - val_accuracy: 0.0239
# Epoch 4/15
# 784/784 [==============================] - 60s 76ms/step - loss: 2.0365 - accuracy: 0.5188 - val_loss: 2.1393 - val_accuracy: 0.0239
# 1e-07
# ***********************************
# model_1 : preprocessing1 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 62s 78ms/step - loss: 2.2504 - accuracy: 0.5348 - val_loss: 12.5238 - val_accuracy: 0.0234
# Epoch 2/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.2398 - accuracy: 0.5352 - val_loss: 13.0908 - val_accuracy: 0.0234
# Epoch 3/15
# 800/800 [==============================] - 61s 77ms/step - loss: 2.2229 - accuracy: 0.5350 - val_loss: 11.8470 - val_accuracy: 0.0234
# Epoch 4/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.2118 - accuracy: 0.5375 - val_loss: 11.5806 - val_accuracy: 0.0234
# Epoch 5/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.2072 - accuracy: 0.5341 - val_loss: 10.1119 - val_accuracy: 0.0234
# Epoch 6/15
# 800/800 [==============================] - 60s 75ms/step - loss: 2.1937 - accuracy: 0.5365 - val_loss: 9.4537 - val_accuracy: 0.0234
# Epoch 7/15
# 800/800 [==============================] - 63s 78ms/step - loss: 2.1867 - accuracy: 0.5370 - val_loss: 8.9281 - val_accuracy: 0.0234
# Epoch 8/15
# 800/800 [==============================] - 61s 77ms/step - loss: 2.1811 - accuracy: 0.5342 - val_loss: 7.8681 - val_accuracy: 0.0236
# Epoch 9/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.1774 - accuracy: 0.5328 - val_loss: 7.5092 - val_accuracy: 0.0258
# Epoch 10/15
# 800/800 [==============================] - 61s 76ms/step - loss: 2.1687 - accuracy: 0.5335 - val_loss: 6.7232 - val_accuracy: 0.0261
# Epoch 11/15
# 800/800 [==============================] - 62s 77ms/step - loss: 2.1632 - accuracy: 0.5328 - val_loss: 6.1130 - val_accuracy: 0.0260
# Epoch 12/15
# 800/800 [==============================] - 63s 78ms/step - loss: 2.1578 - accuracy: 0.5318 - val_loss: 5.4552 - val_accuracy: 0.0300
# Epoch 13/15
# 800/800 [==============================] - 63s 79ms/step - loss: 2.1512 - accuracy: 0.5330 - val_loss: 4.9279 - val_accuracy: 0.0327
# Epoch 14/15
# 800/800 [==============================] - 62s 78ms/step - loss: 2.1458 - accuracy: 0.5330 - val_loss: 4.7254 - val_accuracy: 0.0379
# Epoch 15/15
# 800/800 [==============================] - 63s 79ms/step - loss: 2.1423 - accuracy: 0.5302 - val_loss: 4.1712 - val_accuracy: 0.0641
# ***********************************
# model_2 : preprocessing1 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 800/800 [==============================] - 63s 79ms/step - loss: 2.3711 - accuracy: 0.4575 - val_loss: 1.6412 - val_accuracy: 0.9766
# Epoch 2/15
# 800/800 [==============================] - 63s 78ms/step - loss: 2.3520 - accuracy: 0.4572 - val_loss: 1.6671 - val_accuracy: 0.9604
# Epoch 3/15
# 800/800 [==============================] - 63s 79ms/step - loss: 2.3328 - accuracy: 0.4608 - val_loss: 1.6832 - val_accuracy: 0.9461
# Epoch 4/15
# 800/800 [==============================] - 62s 78ms/step - loss: 2.3145 - accuracy: 0.4602 - val_loss: 1.6999 - val_accuracy: 0.9297
# ***********************************
# model_3 : preprocessing2 with scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.2126 - accuracy: 0.4951 - val_loss: 15.3239 - val_accuracy: 0.0239
# Epoch 2/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.1970 - accuracy: 0.4927 - val_loss: 15.9283 - val_accuracy: 0.0239
# Epoch 3/15
# 784/784 [==============================] - 60s 77ms/step - loss: 2.1854 - accuracy: 0.4966 - val_loss: 15.7675 - val_accuracy: 0.0239
# Epoch 4/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.1724 - accuracy: 0.5010 - val_loss: 15.7691 - val_accuracy: 0.0239
# ***********************************
# model_4 : preprocessing2 without scale
# ***********************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 128)               50304
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense (Dense)                (None, 512)               66048
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 284,289
# Trainable params: 282,497
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/15
# 784/784 [==============================] - 60s 77ms/step - loss: 2.1837 - accuracy: 0.4969 - val_loss: 2.0464 - val_accuracy: 0.3421
# Epoch 2/15
# 784/784 [==============================] - 61s 77ms/step - loss: 2.1684 - accuracy: 0.4963 - val_loss: 2.0577 - val_accuracy: 0.3575
# Epoch 3/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.1592 - accuracy: 0.4993 - val_loss: 2.0579 - val_accuracy: 0.3519
# Epoch 4/15
# 784/784 [==============================] - 61s 78ms/step - loss: 2.1552 - accuracy: 0.4977 - val_loss: 2.0586 - val_accuracy: 0.3434
